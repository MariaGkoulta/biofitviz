# %% [markdown]
# ## Assign equipment category to exercises

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from openai import OpenAI
import re
from dotenv import load_dotenv

# %%
_ = load_dotenv()

# %%
dataframes = {}
data_folder = '../data_processed/'
for filename in os.listdir(data_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(data_folder, filename)
        df = pd.read_csv(file_path)
        dataframes[filename[:-4]] = df
for name, df in dataframes.items():
    print(f"Columns in dataframe '{name}':")
    print(df.columns)
    print()
exercises = dataframes['exercises_cleaned']
null_values_exercises = exercises.isnull().sum()
print("\nNull values in exercises dataframe:")
print(null_values_exercises)
# Out:
# /var/folders/3f/hpgbw8dd459305qvgctxmywc0000gn/T/ipykernel_25206/2847802780.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/3f/hpgbw8dd459305qvgctxmywc0000gn/T/ipykernel_25206/2847802780.py:6: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/3f/hpgbw8dd459305qvgctxmywc0000gn/T/ipykernel_25206/2847802780.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/3f/hpgbw8dd459305qvgctxmywc0000gn/T/ipykernel_25206/2847802780.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Columns in dataframe 'processed_exercises_v2':
# Index(['CloudId', 'Gender', 'Age', 'PhysicalActivityMacroTypeName',
#        'ExerciseName', 'EquipmentName', 'DoneOnUTC', 'Duration_sec',
#        'Calories', 'MetsMin', 'ExerciseBodyPartName', 'ExerciseMusclesName',
#        'METs', 'EquipmentCategory', 'Week', 'Year', 'Date'],
#       dtype='object')
#
# Columns in dataframe 'body_part_categorized':
# Index(['Leg Curl Biostr:LowerBody'], dtype='object')
#
# Columns in dataframe 'exercises_cleaned':
# Index(['CloudId', 'Gender', 'Age', 'PhysicalActivityMacroTypeName',
#        'ExerciseName', 'EquipmentName', 'DoneOnUTC', 'Duration_sec',
#        'Calories', 'MetsMin', 'ExerciseBodyPartName', 'ExerciseMusclesName',
#        'METs'],
#       dtype='object')
#
# Columns in dataframe 'biometrics_cleaned':
# Index(['CloudId', 'Gender', 'Age', 'BiometricName', 'MeasureProvidedBy',
#        'MeasuredOnUTC', 'Value'],
#       dtype='object')
#
# Columns in dataframe 'workout_metrics':
# Index(['CloudId', 'Date', 'WorkoutId', 'total_workout_duration',
#        'total_calories_burnt', 'total_cardio_calories',
#        'total_cardio_duration', 'total_isotonic_calories',
#        'total_isotonic_duration', 'duration_core', 'duration_lower_body',
#        'duration_total_body', 'duration_upper_body', 'duration_cardiovascular',
#        'duration_flexibility_mobility', 'duration_free_weights',
#        'duration_functional_training', 'duration_strength_training',
#        'Intensity'],
#       dtype='object')
#
# Columns in dataframe 'processed_exercises':
# Index(['CloudId', 'Gender', 'Age', 'PhysicalActivityMacroTypeName',
#        'ExerciseName', 'EquipmentName', 'DoneOnUTC', 'Duration_sec',
#        'Calories', 'MetsMin', 'ExerciseBodyPartName', 'ExerciseMusclesName',
#        'METs', 'EquipmentCategory'],
#       dtype='object')
#
# Columns in dataframe 'cluster_quantiles':
# Index(['Cluster', 'Age', 'BMI', 'Basal Metabolic Rate', 'Bone Mass',
#        'Degree Of Obesity Perc', 'Extra Cellular Water Perc', 'Fat Free Mass',
#        'Fat mass Perc', 'Height', 'Intra Cellular Water', 'Left Arm Fat Perc',
#        'Left Leg Fat Perc', 'Metabolic Age', 'Muscle Mass',
#        'Muscle Mass Balance Arm', 'Muscle Mass Balance Leg',
#        'Right Arm Fat Perc', 'Right Leg Fat Perc', 'Standard Body Weight',
#        'Total Body Water Perc', 'Trunk Fat Perc', 'Trunk Muscle Mass',
#        'Visceral Fat Rating', 'Weight', 'Count'],
#       dtype='object')
#
# Columns in dataframe 'merged_workout_metrics':
# Index(['CloudId', 'Date', 'WorkoutId', 'total_workout_duration',
#        'total_calories_burnt', 'total_cardio_calories',
#        'total_cardio_duration', 'total_isotonic_calories',
#        'total_isotonic_duration', 'duration_core', 'duration_lower_body',
#        'duration_total_body', 'duration_upper_body', 'duration_cardiovascular',
#        'duration_flexibility_mobility', 'duration_free_weights',
#        'duration_functional_training', 'duration_strength_training',
#        'Intensity', 'Gender', 'Age'],
#       dtype='object')
#
#
# Null values in exercises dataframe:
# CloudId                                0
# Gender                                 0
# Age                                    0
# PhysicalActivityMacroTypeName          0
# ExerciseName                           0
# EquipmentName                          3
# DoneOnUTC                              0
# Duration_sec                           0
# Calories                               3
# MetsMin                          2456592
# ExerciseBodyPartName              862737
# ExerciseMusclesName               863014
# METs                              870238
# dtype: int64

# %%
# Count the number of rows where both ExerciseBodyPartName and ExerciseMusclesName are null
null_bodypart_muscle_count = exercises[(exercises['ExerciseBodyPartName'].isnull()) & (exercises['ExerciseMusclesName'].isnull())].shape[0]
print(f"Number of rows where both ExerciseBodyPartName and ExerciseMusclesName are null: {null_bodypart_muscle_count}")
# Count the number of rows where either ExerciseBodyPartName or ExerciseMusclesName is null
null_bodypart_or_muscle_count = exercises[(exercises['ExerciseBodyPartName'].isnull()) | (exercises['ExerciseMusclesName'].isnull())].shape[0]
print(f"Number of rows where either ExerciseBodyPartName or ExerciseMusclesName are null: {null_bodypart_or_muscle_count}")
# Out:
# Number of rows where both ExerciseBodyPartName and ExerciseMusclesName are null: 862729
# Number of rows where either ExerciseBodyPartName or ExerciseMusclesName are null: 863022

# %%
# Filter the exercises DataFrame for rows where both ExerciseBodyPartName and ExerciseMusclesName are null
null_bodypart_muscle_examples = exercises[(exercises['ExerciseBodyPartName'].isnull()) & (exercises['ExerciseMusclesName'].isnull())]
null_bodypart_muscle_examples['EquipmentName'].value_counts().head(15)
# Out:
# EquipmentName
# Dumbbells               53564
# Body weight             42543
# Run Artis               23033
# Chest Press Biostr      22352
# Run                     21355
# Low Row Biostr          21338
# Bike Artis              20266
# Vertical Tr. Biostr     20230
# Total Abdom. Biostr     20145
# Barbell                 19147
# Chest Press Sel         17784
# Leg Press Sel           17713
# Leg Extension Biostr    17268
# Leg Curl Biostr         15880
# Bike                    14779
# Name: count, dtype: int64

# %% [markdown]
# ***Replace Bike Artis with Bike and assign it to lowerbody and Run Artis with Run and assign it to totalbody***

# %%
# Replace 'Run Artis' with 'Run' and 'Bike Artis' with 'Bike' in the EquipmentName column
exercises['EquipmentName'] = exercises['EquipmentName'].replace({'Run Artis': 'Run', 'Bike Artis': 'Bike'})

# Update ExerciseBodyPartName based on the EquipmentName
exercises.loc[exercises['EquipmentName'] == 'Run', 'ExerciseBodyPartName'] = 'TotalBody'
exercises.loc[exercises['EquipmentName'] == 'Bike', 'ExerciseBodyPartName'] = 'LowerBody'

# %%
# Count the number of rows where both ExerciseBodyPartName and ExerciseMusclesName are null
null_bodypart_muscle_count = exercises[(exercises['ExerciseBodyPartName'].isnull()) & (exercises['ExerciseMusclesName'].isnull())].shape[0]
print(f"Number of rows where both ExerciseBodyPartName and ExerciseMusclesName are null: {null_bodypart_muscle_count}")
# Filter the exercises DataFrame for rows where both ExerciseBodyPartName and ExerciseMusclesName are null
null_bodypart_muscle_examples = exercises[(exercises['ExerciseBodyPartName'].isnull()) & (exercises['ExerciseMusclesName'].isnull())]
null_bodypart_muscle_examples['EquipmentName'].value_counts().head(15)
# Out:
# Number of rows where both ExerciseBodyPartName and ExerciseMusclesName are null: 783296
# EquipmentName
# Dumbbells               53564
# Body weight             42543
# Chest Press Biostr      22352
# Low Row Biostr          21338
# Vertical Tr. Biostr     20230
# Total Abdom. Biostr     20145
# Barbell                 19147
# Chest Press Sel         17784
# Leg Press Sel           17713
# Leg Extension Biostr    17268
# Leg Curl Biostr         15880
# Leg Extension Sel       14437
# Lat Machine Sel         14324
# Stretching              13503
# Abdominal Crunch Sel    12785
# Name: count, dtype: int64

# %% [markdown]
# ### Equipment

# %%
exercises['EquipmentName'].nunique()
# Out:
# 370

# %% [markdown]
# There are 370 distinct equipment names

# %%
equipment_names_str = ', '.join(exercises['EquipmentName'].dropna().unique())
print(equipment_names_str)
# Out:
# Bike, Run, Leg Curl Biostr, Leg Press Biostr, Leg Extension Sel, Cables Crossed Elt+, Dumbbells, Barbell, Body weight, Kettlebell, Wellness Ball, Climb Excite 1000, Skillrow, Skillrun, Chest Press Sel, Vertical Tr. Artis, Total Abd. Artis, Abductor Artis, Synchro Excite 1000, Climb Excite Live, Tubes, Cable Stations 4, Row Pure, Chest Press Pure, Run Excite 1000, Synchro Excite 700, Arm Extension Sel, Synchro Artis, Bike Excite 1000, Run Excite Live, Rear Kick Pure, Leg Press Sel, Total Abdominal Sel, Lower Back Sel, Synchro Artis 2019, Multipower, Pectoral Sel, Shoulder Press Sel, Anterior Flexability, Run Excite 600, Pulley Sel, Cables Crossed Sel, Total Abdom. Biostr, Vertical Tr. Biostr, Crossover Cables, Recline, Wave, Lat Machine Sel, Arm Extension Artis, Shoulder Press Artis, Low Row Artis, Cable Jungle, Lower Back Bench, Leg Curl Elt+, Leg Curl Sel, Adductor Artis, Chest Press Biostr, Low Row Biostr, Step/Squat Kst, High Pull Kst, Leg Curl Artis, Chest Press Artis, Adductor Sel, Abdominal Crunch Sel, Leg Extension Artis, Vario Excite Live, Vertical Traction Sel, Shoulder P. Biostr, Leg Extension Biostr, Easy Chin/Dip Sel, Plyobox, Technogym Bike, Abductor Sel, Adductor Elt+, Lower Back Biostr, Low Pull Kst, Cambered Barbell, Jump rope, Upper Back Sel, Pectoral Artis, Power band, Low Row Sel, Leg Curl, Recline Excite 1000, Top, Low Row Elt+, Leg Press Elt+, Glute Elt+, Synchro Excite Compact, Synchro, Stretching, Leg Press Pure, Arm Curl Elt+, Abdominal Crunch Elt+, Synchro ARTIS with ramp, Dap Elt+, Lower Back Elt+, Sling trainer, Leg Press Artis, Prone Leg Curl Sel, Vario Excite 1000, Omnia, Climb, Vario Excite 700, Synchro with ramp, Posterior Flexability, Core Crunch Kst, Abductor Elt+, Vario, Run Excite 700, Leg Press Med, Crunch Bench, Synchro Excite LiveR, Core Rotation Kst, Lower Back Artis, Kinesis Omega/One: Vertical, Kn. EasyChinDip Elt+, Rotary Torso Sel, Lat Machine Elt+, Shoulder Press Elt, Cables Crossed Elt, Multi Hip Sel, Lat Machine Artis, Glute Sel, Skillbike, Rear Delt Row Artis, Foam Roller, Arm Curl Artis, Vario Artis, Medicine Ball Arke, Kinesis Omega/One: Low, Multi Hip Artis, Abductor Elt, Adductor Elt, Skillrun TX 500, Vertical Traction Elt+, Chest Press Elt+, Leg Extension Elt+, Run Excite 500, Synchro Excite 500, Pull Down Pure, Pectoral Elt+, Press Kst, Linear Leg Press Pure, Squat Artis, Balance Dome, Rotary Torso Artis, Skillmill, Radiant, Mobility stick, Technogym Ride, Recline Excite Live, Shoulder Press Elt+, Lat Machine Med, Vertical Traction Med, Abdominal Bench, Pectoral/Reverse Fly, Pulldown Sel, Recline Excite 700, Crossover, Bike Excite 700, Ercolina ROM, Bike Excite Live, Biceps Pure, Run Excite 900, Abdominal Crunch Elt, Delt Machine, Pulley, Tricep Station, Abductor Med, Abdominal Crunch Med, Stability Disc, Arm Extension Elt+, Leg Raise / Dip, Rotary Torso, Chest Press, Arm Curl Sel, Kinesis Omega/One: High, Jog Excite 700, Run 25L, Climb Artis, Ab Crunch Elt+, Chin Up/Dip Leg Raise, Calf Pure, Olympic Half Rack Pure, Shoulder Press Med, Reverse Fly Sel, Lat Machine Elt, Leg Press Elt, Leg Extension Biostrength, Overhead Press Kst, Arm Curl Elt, Crunch Bench Elt, Crossover Excite 1000, Lower Back Elt, Wellness Bag, Group Cycle Connect, Shoulder Press Pure, Olympic Rack Pure, Adjustable Bench Elt, MYCYCLING, Step, Leg Extension Bio, Leg Curl Med, Chest Press Biostrength, Vertical Tr. Biostrength, Low Row Biostrength, Low Row Elt, Shoulder P. Biostrength, Leg Curl Biostrength, Stand Leg Curl Pure, Leg Extension Pure, Low Row Pure, Balance Pad, Chest Incline Sel, Top Excite 700, Top Excite 1000, Recline Artis, Leg Curl/Leg Extension, Flat Bench Sel, Crossover Excite 700, Kinesis Gamma, Leg Curl Elt, Pectoral Elt, Kinesis Alpha, Wellness Ball Active Sitting, Incline Chest Press Pure, Rotary Calf Sel, Kinesis Beta, Chest Press Elt, Glute Med, Leg Extension Elt, Vertical Row, Glute Elt, Air Ball, Multipla, Delts Machine Sel, Bike Excite 500, Pectoral Machine, Cross Personal, Water B ...

# %%
equipment_names_str
# Out:
# 'Bike, Run, Leg Curl Biostr, Leg Press Biostr, Leg Extension Sel, Cables Crossed Elt+, Dumbbells, Barbell, Body weight, Kettlebell, Wellness Ball, Climb Excite 1000, Skillrow, Skillrun, Chest Press Sel, Vertical Tr. Artis, Total Abd. Artis, Abductor Artis, Synchro Excite 1000, Climb Excite Live, Tubes, Cable Stations 4, Row Pure, Chest Press Pure, Run Excite 1000, Synchro Excite 700, Arm Extension Sel, Synchro Artis, Bike Excite 1000, Run Excite Live, Rear Kick Pure, Leg Press Sel, Total Abdominal Sel, Lower Back Sel, Synchro Artis 2019, Multipower, Pectoral Sel, Shoulder Press Sel, Anterior Flexability, Run Excite 600, Pulley Sel, Cables Crossed Sel, Total Abdom. Biostr, Vertical Tr. Biostr, Crossover Cables, Recline, Wave, Lat Machine Sel, Arm Extension Artis, Shoulder Press Artis, Low Row Artis, Cable Jungle, Lower Back Bench, Leg Curl Elt+, Leg Curl Sel, Adductor Artis, Chest Press Biostr, Low Row Biostr, Step/Squat Kst, High Pull Kst, Leg Curl Artis, Chest Press Artis, Adductor Sel, Abdominal Crunch Sel, Leg Extension Artis, Vario Excite Live, Vertical Traction Sel, Shoulder P. Biostr, Leg Extension Biostr, Easy Chin/Dip Sel, Plyobox, Technogym Bike, Abductor Sel, Adductor Elt+, Lower Back Biostr, Low Pull Kst, Cambered Barbell, Jump rope, Upper Back Sel, Pectoral Artis, Power band, Low Row Sel, Leg Curl, Recline Excite 1000, Top, Low Row Elt+, Leg Press Elt+, Glute Elt+, Synchro Excite Compact, Synchro, Stretching, Leg Press Pure, Arm Curl Elt+, Abdominal Crunch Elt+, Synchro ARTIS with ramp, Dap Elt+, Lower Back Elt+, Sling trainer, Leg Press Artis, Prone Leg Curl Sel, Vario Excite 1000, Omnia, Climb, Vario Excite 700, Synchro with ramp, Posterior Flexability, Core Crunch Kst, Abductor Elt+, Vario, Run Excite 700, Leg Press Med, Crunch Bench, Synchro Excite LiveR, Core Rotation Kst, Lower Back Artis, Kinesis Omega/One: Vertical, Kn. EasyChinDip Elt+, Rotary Torso Sel, Lat Machine Elt+, Shoulder Press Elt, Cables Crossed Elt, Multi Hip Sel, Lat Machine Artis, Glute Sel, Skillbike, Rear Delt Row Artis, Foam Roller, Arm Curl Artis, Vario Artis, Medicine Ball Arke, Kinesis Omega/One: Low, Multi Hip Artis, Abductor Elt, Adductor Elt, Skillrun TX 500, Vertical Traction Elt+, Chest Press Elt+, Leg Extension Elt+, Run Excite 500, Synchro Excite 500, Pull Down Pure, Pectoral Elt+, Press Kst, Linear Leg Press Pure, Squat Artis, Balance Dome, Rotary Torso Artis, Skillmill, Radiant, Mobility stick, Technogym Ride, Recline Excite Live, Shoulder Press Elt+, Lat Machine Med, Vertical Traction Med, Abdominal Bench, Pectoral/Reverse Fly, Pulldown Sel, Recline Excite 700, Crossover, Bike Excite 700, Ercolina ROM, Bike Excite Live, Biceps Pure, Run Excite 900, Abdominal Crunch Elt, Delt Machine, Pulley, Tricep Station, Abductor Med, Abdominal Crunch Med, Stability Disc, Arm Extension Elt+, Leg Raise / Dip, Rotary Torso, Chest Press, Arm Curl Sel, Kinesis Omega/One: High, Jog Excite 700, Run 25L, Climb Artis, Ab Crunch Elt+, Chin Up/Dip Leg Raise, Calf Pure, Olympic Half Rack Pure, Shoulder Press Med, Reverse Fly Sel, Lat Machine Elt, Leg Press Elt, Leg Extension Biostrength, Overhead Press Kst, Arm Curl Elt, Crunch Bench Elt, Crossover Excite 1000, Lower Back Elt, Wellness Bag, Group Cycle Connect, Shoulder Press Pure, Olympic Rack Pure, Adjustable Bench Elt, MYCYCLING, Step, Leg Extension Bio, Leg Curl Med, Chest Press Biostrength, Vertical Tr. Biostrength, Low Row Biostrength, Low Row Elt, Shoulder P. Biostrength, Leg Curl Biostrength, Stand Leg Curl Pure, Leg Extension Pure, Low Row Pure, Balance Pad, Chest Incline Sel, Top Excite 700, Top Excite 1000, Recline Artis, Leg Curl/Leg Extension, Flat Bench Sel, Crossover Excite 700, Kinesis Gamma, Leg Curl Elt, Pectoral Elt, Kinesis Alpha, Wellness Ball Active Sitting, Incline Chest Press Pure, Rotary Calf Sel, Kinesis Beta, Chest Press Elt, Glute Med, Leg Extension Elt, Vertical Row, Glute Elt, Air Ball, Multipla, Delts Machine Sel, Bike Excite 500, Pectoral Machine, Cross Personal, Water  ...

# %%
# Split the string by commas and count the number of resulting values
num_values = len(equipment_names_str.split(','))
print(f"The equipment_names_str string has {num_values} values.")
# Out:
# The equipment_names_str string has 370 values.

# %%
# Split the string by commas to get a list of equipment names
equipment_list = equipment_names_str.split(', ')

# %% [markdown]
# Functional training refers to a style of exercise that focuses on improving your ability to perform everyday movements more effectively and safely. It emphasizes exercises that mimic real-life activities and engage multiple muscle groups and joints, making your body stronger and more coordinated for daily tasks, sports, or physically demanding activities.

# %%
openaikey = os.getenv('OPENAIKEY')
client = OpenAI(api_key=openaikey)

# Function to split a list into batches
def split_into_batches(lst, batch_size):
    for i in range(0, len(lst), batch_size):
        yield lst[i:i + batch_size]

# Configurable batch size
batch_size = 10

# Split the equipment_list into batches
batches = list(split_into_batches(equipment_list, batch_size))

# Initialize an empty string to store the concatenated response
full_response = ""

# Loop through each batch and make the API call
for batch in batches:
    equipment_names = ', '.join(batch)
    
    # Prepare the prompt for the OpenAI API
    prompt = "Categorize the following gym equipment into the following broader categories -Strength Training, Free Weights, Functional Training, Cardiovascular, Flexibility & Mobility-  Add everything only to one category. Dont skip any strings and dont change them at all from the way I give it to you. Give it in the form equip:category (next row)equip:category Don't write anything else. Also write each equipment seperately (next line)\n\n"
    prompt += equipment_names

    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful fitness data analysis assistant."},
                {"role": "user", "content": prompt}
            ]
        )
        response = completion.choices[0].message.content
        print(response)
        full_response += response + "\n"
    except Exception as e:
        print(f"RateLimitError: {e}")

print(full_response)
# Out:
# Bike:Cardiovascular
# Run:Cardiovascular
# Leg Curl Biostr:Strength Training
# Leg Press Biostr:Strength Training
# Leg Extension Sel:Strength Training
# Cables Crossed Elt+:Functional Training
# Dumbbells:Free Weights
# Barbell:Free Weights
# Body weight:Functional Training
# Kettlebell:Functional Training
# Wellness Ball:Flexibility & Mobility
# Climb Excite 1000:Cardiovascular
# Skillrow:Cardiovascular
# Skillrun:Cardiovascular
# Chest Press Sel:Strength Training
# Vertical Tr. Artis:Functional Training
# Total Abd. Artis:Functional Training
# Abductor Artis:Functional Training
# Synchro Excite 1000:Cardiovascular
# Climb Excite Live:Cardiovascular
# Tubes, Cable Stations: Functional Training
# Row Pure: Strength Training
# Chest Press Pure: Strength Training
# Run Excite 1000: Cardiovascular
# Synchro Excite 700: Cardiovascular
# Arm Extension Sel: Strength Training
# Synchro Artis: Cardiovascular
# Bike Excite 1000: Cardiovascular
# Run Excite Live: Cardiovascular
# Rear Kick Pure:Functional Training
# Leg Press Sel:Strength Training
# Total Abdominal Sel:Strength Training
# Lower Back Sel:Strength Training
# Synchro Artis 2019:Cardiovascular
# Multipower:Strength Training
# Pectoral Sel:Strength Training
# Shoulder Press Sel:Strength Training
# Anterior Flexability:Flexibility & Mobility
# Run Excite 600:Cardiovascular
# Pulley Sel:Functional Training
# Cables Crossed Sel:Functional Training
# Total Abdom. Biostr:Strength Training
# Vertical Tr. Biostr:Strength Training
# Crossover Cables:Strength Training
# Recline:Strength Training
# Wave:Cardiovascular
# Lat Machine Sel:Strength Training
# Arm Extension Artis:Strength Training
# Shoulder Press Artis:Strength Training
# Low Row Artis:Strength Training
# Cable Jungle:Functional Training
# Lower Back Bench:Strength Training
# Leg Curl Elt+:Strength Training
# Leg Curl Sel:Strength Training
# Adductor Artis:Strength Training
# Chest Press Biostr:Strength Training
# Low Row Biostr:Strength Training
# Step/Squat Kst:Functional Training
# High Pull Kst:Strength Training
# Leg Curl Artis: Strength Training
# Chest Press Artis: Strength Training
# Adductor Sel: Strength Training
# Abdominal Crunch Sel: Strength Training
# Leg Extension Artis: Strength Training
# Vario Excite Live: Cardiovascular
# Vertical Traction Sel: Strength Training
# Shoulder P. Biostr: Strength Training
# Leg Extension Biostr: Strength Training
# Easy Chin/Dip Sel: Strength Training
# Plyobox:Functional Training
# Technogym Bike:Cardiovascular
# Abductor Sel:Strength Training
# Adductor Elt+:Strength Training
# Lower Back Biostr:Strength Training
# Low Pull Kst:Strength Training
# Cambered Barbell:Free Weights
# Jump rope:Cardiovascular
# Upper Back Sel:Strength Training
# Pectoral Artis:Strength Training
# Power band:Functional Training
# Low Row Sel:Strength Training
# Leg Curl:Strength Training
# Recline Excite 1000:Cardiovascular
# Top:Strength Training
# Low Row Elt+:Strength Training
# Leg Press Elt+:Strength Training
# Glute Elt+:Strength Training
# Synchro Excite Compact:Cardiovascular
# Synchro:Cardiovascular
# Stretching:Flexibility & Mobility
# Leg Press Pure:Strength Training
# Arm Curl Elt+:Strength Training
# Abdominal Crunch Elt+:Strength Training
# Synchro ARTIS with ramp:Cardiovascular
# Dap Elt+:Functional Training
# Lower Back Elt+:Strength Training
# Sling trainer:Functional Training
# Leg Press Artis:Strength Training
# Prone Leg Curl Sel:Strength Training
# Vario Excite 1000:Cardiovascular
# Omnia:Functional Training
# Climb:Cardiovascular
# Vario Excite 700:Cardiovascular
# Synchro with ramp:Cardiovascular
# Posterior Flexability:Flexibility & Mobility
# Core Crunch Kst:Strength Training
# Abductor Elt+:Strength Training
# Vario:Cardiovascular
# Run Excite 700:Cardiovascular
# Leg Press Med:Strength Training
# Crunch Bench:Strength Training
# Synchro Excite LiveR:Cardiovascular
# Core Rotation Kst:Functional Training
# Lower Back Artis:Strength Training
# Kinesis Omega/One: Vertical:Functional Training
# Kn. EasyChinDip Elt+:Strength Training
# Rotary Torso Sel:Strength Training
# Lat Machine Elt+:Strength Training
# Shoulder Press Elt:Strength Training
# Cables Crossed Elt:Functional Training
# Multi Hip Sel:Strength Training
# Lat Machine Artis:Strength Training
# Glute Sel:Strength Training
# Skillbike:Cardiovascular
# Rear Delt Row Artis:Strength Training
# Foam Roller:Flexibility & Mobility
# Arm Curl Artis:Strength Training
# Vario Artis:Cardiovascular
# Medicine Ball Arke:Functional Training
# Kinesis Omega/One: Functional Training
# Multi Hip Artis: Strength Training
# Abductor Elt: Strength Training
# Adductor Elt: Strength Training
# Skillrun TX 500: Cardiovascular
# Vertical Traction Elt+: Strength Training
# Chest Press Elt+: Strength Training
# Leg Extension Elt+: Strength Training
# Run Excite 500: Cardiovascular
# Synchro Excite 500: Cardiovascular
# Pull Down Pure: Strength Training
# Pectoral Elt+: Strength Training
# Press Kst: Strength Training
# Linear Leg Press Pure: Strength Training
# Squat Artis: Strength Training
# Balance Dome: Functional Training
# Rotary Torso Artis: Strength Training
# Skillmill: Cardiovascular
# Radiant: Cardiovascular
# Mobility stick: Flexibility & Mobility
# Technogym Ride:Cardiovascular
# Recline Excite Live:Cardiovascular
# Shoulder Press Elt+:Strength Training
# Lat Machine Med:Strength Training
# Vertical Traction Med:Strength Training
# Abdominal Bench:Strength Training
# Pectoral/Reverse Fly:Strength Training
# Pulldown Sel:Strength Training
# Recline Excite 700:Cardiovascular
# Crossover:Functional Training
# Bike Excite 700:Cardiovascular
# Ercolina ROM:Flexibility & Mobility
# Bike Excite Live:Cardiovascular
# Biceps Pure:Strength Training
# Run Excite 900:Cardiovascular
# Abdominal Crunch Elt:Strength Training
# Delt Machine:Strength Training
# Pulley:Strength Training
# Tricep Station:Strength Training
# Abductor Med:Strength Training
# Abdominal Crunch Med:Strength Training
# Stability Disc:Functional Training
# Arm Extension Elt+:Strength Training
# Leg Raise / Dip:Strength Training
# Rotary Torso:Strength Training
# Chest Press:Strength Training
# Arm Curl Sel:Strength Training
# Kinesis Omega/One: High:Strength Training
# Jog Excite 700:Cardiovascular
# Run 25L:Cardiovascular
# Climb Artis:Cardiovascular
# Ab Crunch Elt+:Strength Training
# Chin Up/Dip Leg Raise:Functional Training
# Calf Pure:Strength Training
# Olympic Half Rack Pure:Strength Training
# Shoulder Press Med:Strength Training
# Reverse Fly Sel:Strength Training
# Lat Machine Elt:Strength Training
# Leg Press Elt:Strength Training
# Leg Extension Biostrength:Strength Training
# Overhead Press Kst:Strength Training
# Arm Curl Elt:Strength Training
# Crunch Bench Elt:Strength Training
# Crossover Excite 1000:Functional Training
# Lower Back Elt:Strength Training
# Wellness Bag:Functional Training
# Group Cycle Connect:Cardiovascular
# Shoulder Press Pure:Strength Training
# Olympic Rack Pure:Strength Training
# Adjustable Bench Elt:Strength Training
# MYCYCLING:Cardiovascular
# Step:Cardiovascular
# Leg Extension Bio:Strength Training
# Leg Curl Med:Strength Training
# Chest Press Biostrength:Strength Training
# Vertical Tr. Biostrength:Strength Training
# Low Row Biostrength:Strength Training
# Low Row Elt:Strength Training
# Shoulder P. Biostrength:Strength Training
# Leg Curl Biostrength:Strength Training
# Stand Leg Curl Pure: Strength Training
# Leg Extension Pure: Strength Training
# Low Row Pure: Strength Training
# Balance Pad: Flexibility & Mobility
# Chest Incline Sel: Strength Training
# Top Excite 700: Cardiovascular
# Top Excite 1000: Cardiovascular
# Recline Artis: Cardiovascular
# Leg Curl/Leg Extension: Strength Training
# Flat Bench Sel: Strength Training
# Crossover Excite 700:Cardiovascular
# Kinesis Gamma:Functional Training
# Leg Curl Elt:Strength Training
# Pectoral Elt:Strength Training
# Kinesis Alpha:Functional Training
# Wellness Ball Active Sitting:Flexibility & Mobility
# Incline Chest Press Pure:Strength Training
# Rotary Calf Sel:Strength Training
# Kinesis Beta:Functional Training
# Chest Press Elt:Strength Training
# Glute Med:Strength Training
# Leg Extension Elt:Strength Training
# Vertical Row:Strength Training
# Glute Elt:Strength Training
# Air Ball:Functional Training
# Multipla:Strength Training
# Delts Machine Sel:Strength Training
# Bike Excite 500:Cardiovascular
# Pectoral Machine:Strength Training
# Cross Personal:Cardiovascular
# Water Ball:Functional Training
# Abductor/Adductor:Strength Training
# Pratica:Strength Training
# Pendulum:Strength Training
# Power Personal:Strength Training
# Unica:Strength Training
# Standing Leg Curl:Strength Training
# Wide Chest Press Pure:Strength Training
# Leg Press Disc Load:Strength Training
# Slam ball:Functional Training
# Wellness Rack, Vertical Traction Bio, Rowing Torso Bio, Vertical Traction Elt, Leg Extension Med, Hexagon dumbbells, Abdominal Crunch ROM, Loop band, Lat Machine, Leg extension ROM
# Strength Training
# Tricep Press:Strength Training
# Cross Over Cables:Strength Training
# Medicine Ball:Functional Training
# Seated Dip Pure:Strength Training
# Vario Excite 500:Cardiovascular
# Top Excite Live:Cardiovascular
# Gym Ladder:Functional Training
# Lower Back Med:Functional Training
# Ercolina Rehab Elt+:Flexibility & Mobility
# Water 8ball:Functional Training
# Battle Rope:Functional Training
# Synchro without ramp:Cardiovascular
# Chest Press Med:Strength Training
# Hip Thrust Pure:Strength Training
# Kinesis Delta:Functional Training
# Elastic band:Flexibility & Mobility
# Kettle Blocks:Free Weights
# Arm Curl:Strength Training
# Run Personal:Cardiovascular
# Multi Hip Med:Strength Training
# Step Excite 1000:Cardiovascular
# Vertical Traction:Strength Training
# Easy Power Station:Strength Training
# Calf Machine Standing:Strength Training
# Chest Press Bio:Strength Training
# Bike 12L:Cardiovascular
# Row Race:Cardiovascular
# Step Excite 700:Cardiovascular
# Adductor Machine:Strength Training
# Arm Extension Elt:Strength Training
# Calf Machine Sitting: Strength Training
# Rings: Functional Training
# Hack Squat Pure: Strength Training
# Wave Excite 700: Cardiovascular
# Seated Calf Pure: Strength Training
# Abdominal Crunch Bio: Strength Training
# Synchro Excite Live: Cardiovascular
# Recline Personal: Flexibility & Mobility
# Technogym Bench: Strength Training
# Abductor Machine: Strength Training
# Ercolina Rehab Sel:Flexibility & Mobility
# Standing Abductor Pure:Strength Training
# Bike Med:Cardiovascular
# Low Row Med:Strength Training
# Lower Back ROM:Flexibility & Mobility
# Shoulder Press:Strength Training
# Upper Back Med:Strength Training
# Pullover Machine:Strength Training
# Horizontal Leg Press:Strength Training
# Lower Back Bio:Functional Training
# Ball Trampoline: Functional Training
# Crossover Excite 500: Cardiovascular
# Adjustable Ab/Crunch Pure: Strength Training
# Technogym Cycle: Cardiovascular
# Training ladder: Functional Training
# Big Tubing: Functional Training
# Bike Personal: Cardiovascular
# Standing Gluteus: Strength Training
# Sitting Leg Curl ROM: Strength Training
# Activities: Functional Training
# Recline Excite 500:Cardiovascular
# GHD Bench:Functional Training
# Leg Press Biostrength:Strength Training
# Lower Back Biostrength:Strength Training
# Total Abdom. Biostrength:Strength Training
# Speed ladder:Functional Training
# Dips Bar:Strength Training
# Kinesis Personal:Functional Training
# T-Row Bar:Strength Training
# Adductor Med:Strength Training
# Pectoral Med:Strength Training
# Ercolina Med:Strength Training
# Smart dips bar:Strength Training
# Pullover Pure:Strength Training
# Technogym Elliptical:Cardiovascular
# High & Low Pull Plr:Strength Training
# Leg press REV:Strength Training
# Jog Excite 500:Cardiovascular
# Kinesis Personal Beta:Functional Training
# Kinesis Personal Gamma:Functional Training
# Leg extension REV:Strength Training
# Rotary Torso Med:Functional Training
# Twin Clubs:Functional Training
# Press & Overhead Press Plr:Strength Training
# Step Excite 500:Cardiovascular
# Leg Curl Bio:Strength Training
# Leg Press Bio:Strength Training
# Myrun:Cardiovascular
# Unica Classic:Strength Training
# Plyo Board:Functional Training
# Hamstring Gluteus:Functional Training
# Pull-up bar:Strength Training
# Mobility ball:Flexibility & Mobility
# Rotex XT:Strength Training
# Bike Excite 700 12L:Cardiovascular
# Bike REV:Cardiovascular
# Synchro Forma:Cardiovascular
# Technogym Run:Cardiovascular
# Run Med:Cardiovascular
# Jumping box H600:Functional Training
# Battle rope:Functional Training
# Wave Excite 500:Cardiovascular
# Core & Leg Ext-Curl Plr:Strength Training
# Jumping box H300:Functional Training
# Run XT:Cardiovascular
# Punching bag:Functional Training
# Lat bar:Strength Training
# Pistols:Functional Training
# Wall bar:Functional Training
# Kinesis Personal Stretch:Flexibility & Mobility
# Bike:Cardiovascular
# Run:Cardiovascular
# Leg Curl Biostr:Strength Training
# Leg Press Biostr:Strength Training
# Leg Extension Sel:Strength Training
# Cables Crossed Elt+:Functional Training
# Dumbbells:Free Weights
# Barbell:Free Weights
# Body weight:Functional Training
# Kettlebell:Functional Training
# Wellness Ball:Flexibility & Mobility
# Climb Excite 1000:Cardiovascular
# Skillrow:Cardiovascular
# Skillrun:Cardiovascular
# Chest Press Sel:Strength Training
# Vertical Tr. Artis:Functional Training
# Total Abd. Artis:Functional Training
# Abductor Artis:Functional Training
# Synchro Excite 1000:Cardiovascular
# Climb Excite Live:Cardiovascular
# Tubes, Cable Stations: Functional Training
# Row Pure: Strength Training
# Chest Press Pure: Strength Training
# Run Excite 1000: Cardiovascular
# Synchro Excite 700: Cardiovascular
# Arm Extension Sel: Strength Training
# Synchro Artis: Cardiovascular
# Bike Excite 1000: Cardiovascular
# Run Excite Live: Cardiovascular
# Rear Kick Pure:Functional Training
# Leg Press Sel:Strength Training
# Total Abdominal Sel:Strength Training
# Lower Back Sel:Strength Training
# Synchro Artis 2019:Cardiovascular
# Multipower:Strength Training
# Pectoral Sel:Strength Training
# Shoulder Press Sel:Strength Training
# Anterior Flexability:Flexibility & Mobility
# Run Excite 600:Cardiovascular
# Pulley Sel:Functional Training
# Cables Crossed Sel:Functional Training
# Total Abdom. Biostr:Strength Training
# Vertical Tr. Biostr:Strength Training
# Crossover Cables:Strength Training
# Recline:Strength Training
# Wave:Cardiovascular
# Lat Machine Sel:Strength Training
# Arm Extension Artis:Strength Training
# Shoulder Press Artis:Strength Training
# Low Row Artis:Strength Training
# Cable Jungle:Functional Training
# Lower Back Bench:Strength Training
# Leg Curl Elt+:Strength Training
# Leg Curl Sel:Strength Training
# Adductor Artis:Strength Training
# Chest Press Biostr:Strength Training
# Low Row Biostr:Strength Training
# Step/Squat Kst:Functional Training
# High Pull Kst:Strength Training
# Leg Curl Artis: Strength Training
# Chest Press Artis: Strength Training
# Adductor Sel: Strength Training
# Abdominal Crunch Sel: Strength Training
# Leg Extension Artis: Strength Training
# Vario Excite Live: Cardiovascular
# Vertical Traction Sel: Strength Training
# Shoulder P. Biostr: Strength Training
# Leg Extension Biostr: Strength Training
# Easy Chin/Dip Sel: Strength Training
# Plyobox:Functional Training
# Technogym Bike:Cardiovascular
# Abductor Sel:Strength Training
# Adductor Elt+:Strength Training
# Lower Back Biostr:Strength Training
# Low Pull Kst:Strength Training
# Cambered Barbell:Free Weights
# Jump rope:Cardiovascular
# Upper Back Sel:Strength Training
# Pectoral Artis:Strength Training
# Power band:Functional Training
# Low Row Sel:Strength Training
# Leg Curl:Strength Training
# Recline Excite 1000:Cardiovascular
# Top:Strength Training
# Low Row Elt+:Strength Training
# Leg Press Elt+:Strength Training
# Glute Elt+:Strength Training
# Synchro Excite Compact:Cardiovascular
# Synchro:Cardiovascular
# Stretching:Flexibility & Mobility
# Leg Press Pure:Strength Training
# Arm Curl Elt+:Strength Training
# Abdominal Crunch Elt+:Strength Training
# Synchro ARTIS with ramp:Cardiovascular
# Dap Elt+:Functional Training
# Lower Back Elt+:Strength Training
# Sling trainer:Functional Training
# Leg Press Artis:Strength Training
# Prone Leg Curl Sel:Strength Training
# Vario Excite 1000:Cardiovascular
# Omnia:Functional Training
# Climb:Cardiovascular
# Vario Excite 700:Cardiovascular
# Synchro with ramp:Cardiovascular
# Posterior Flexability:Flexibility & Mobility
# Core Crunch Kst:Strength Training
# Abductor Elt+:Strength Training
# Vario:Cardiovascular
# Run Excite 700:Cardiovascular
# Leg Press Med:Strength Training
# Crunch Bench:Strength Training
# Synchro Excite LiveR:Cardiovascular
# Core Rotation Kst:Functional Training
# Lower Back Artis:Strength Training
# Kinesis Omega/One: Vertical:Functional Training
# Kn. EasyChinDip Elt+:Strength Training
# Rotary Torso Sel:Strength Training
# Lat Machine Elt+:Strength Training
# Shoulder Press Elt:Strength Training
# Cables Crossed Elt:Functional Training
# Multi Hip Sel:Strength Training
# Lat Machine Artis:Strength Training
# Glute Sel:Strength Training
# Skillbike:Cardiovascular
# Rear Delt Row Artis:Strength Training
# Foam Roller:Flexibility & Mobility
# Arm Curl Artis:Strength Training
# Vario Artis:Cardiovascular
# Medicine Ball Arke:Functional Training
# Kinesis Omega/One: Functional Training
# Multi Hip Artis: Strength Training
# Abductor Elt: Strength Training
# Adductor Elt: Strength Training
# Skillrun TX 500: Cardiovascular
# Vertical Traction Elt+: Strength Training
# Chest Press Elt+: Strength Training
# Leg Extension Elt+: Strength Training
# Run Excite 500: Cardiovascular
# Synchro Excite 500: Cardiovascular
# Pull Down Pure: Strength Training
# Pectoral Elt+: Strength Training
# Press Kst: Strength Training
# Linear Leg Press Pure: Strength Training
# Squat Artis: Strength Training
# Balance Dome: Functional Training
# Rotary Torso Artis: Strength Training
# Skillmill: Cardiovascular
# Radiant: Cardiovascular
# Mobility stick: Flexibility & Mobility
# Technogym Ride:Cardiovascular
# Recline Excite Live:Cardiovascular
# Shoulder Press Elt+:Strength Training
# Lat Machine Med:Strength Training
# Vertical Traction Med:Strength Training
# Abdominal Bench:Strength Training
# Pectoral/Reverse Fly:Strength Training
# Pulldown Sel:Strength Training
# Recline Excite 700:Cardiovascular
# Crossover:Functional Training
# Bike Excite 700:Cardiovascular
# Ercolina ROM:Flexibility & Mobility
# Bike Excite Live:Cardiovascular
# Biceps Pure:Strength Training
# Run Excite 900:Cardiovascular
# Abdominal Crunch Elt:Strength Training
# Delt Machine:Strength Training
# Pulley:Strength Training
# Tricep Station:Strength Training
# Abductor Med:Strength Training
# Abdominal Crunch Med:Strength Training
# Stability Disc:Functional Training
# Arm Extension Elt+:Strength Training
# Leg Raise / Dip:Strength Training
# Rotary Torso:Strength Training
# Chest Press:Strength Training
# Arm Curl Sel:Strength Training
# Kinesis Omega/One: High:Strength Training
# Jog Excite 700:Cardiovascular
# Run 25L:Cardiovascular
# Climb Artis:Cardiovascular
# Ab Crunch Elt+:Strength Training
# Chin Up/Dip Leg Raise:Functional Training
# Calf Pure:Strength Training
# Olympic Half Rack Pure:Strength Training
# Shoulder Press Med:Strength Training
# Reverse Fly Sel:Strength Training
# Lat Machine Elt:Strength Training
# Leg Press Elt:Strength Training
# Leg Extension Biostrength:Strength Training
# Overhead Press Kst:Strength Training
# Arm Curl Elt:Strength Training
# Crunch Bench Elt:Strength Training
# Crossover Excite 1000:Functional Training
# Lower Back Elt:Strength Training
# Wellness Bag:Functional Training
# Group Cycle Connect:Cardiovascular
# Shoulder Press Pure:Strength Training
# Olympic Rack Pure:Strength Training
# Adjustable Bench Elt:Strength Training
# MYCYCLING:Cardiovascular
# Step:Cardiovascular
# Leg Extension Bio:Strength Training
# Leg Curl Med:Strength Training
# Chest Press Biostrength:Strength Training
# Vertical Tr. Biostrength:Strength Training
# Low Row Biostrength:Strength Training
# Low Row Elt:Strength Training
# Shoulder P. Biostrength:Strength Training
# Leg Curl Biostrength:Strength Training
# Stand Leg Curl Pure: Strength Training
# Leg Extension Pure: Strength Training
# Low Row Pure: Strength Training
# Balance Pad: Flexibility & Mobility
# Chest Incline Sel: Strength Training
# Top Excite 700: Cardiovascular
# Top Excite 1000: Cardiovascular
# Recline Artis: Cardiovascular
# Leg Curl/Leg Extension: Strength Training
# Flat Bench Sel: Strength Training
# Crossover Excite 700:Cardiovascular
# Kinesis Gamma:Functional Training
# Leg Curl Elt:Strength Training
# Pectoral Elt:Strength Training
# Kinesis Alpha:Functional Training
# Wellness Ball Active Sitting:Flexibility & Mobility
# Incline Chest Press Pure:Strength Training
# Rotary Calf Sel:Strength Training
# Kinesis Beta:Functional Training
# Chest Press Elt:Strength Training
# Glute Med:Strength Training
# Leg Extension Elt:Strength Training
# Vertical Row:Strength Training
# Glute Elt:Strength Training
# Air Ball:Functional Training
# Multipla:Strength Training
# Delts Machine Sel:Strength Training
# Bike Excite 500:Cardiovascular
# Pectoral Machine:Strength Training
# Cross Personal:Cardiovascular
# Water Ball:Functional Training
# Abductor/Adductor:Strength Training
# Pratica:Strength Training
# Pendulum:Strength Training
# Power Personal:Strength Training
# Unica:Strength Training
# Standing Leg Curl:Strength Training
# Wide Chest Press Pure:Strength Training
# Leg Press Disc Load:Strength Training
# Slam ball:Functional Training
# Wellness Rack, Vertical Traction Bio, Rowing Torso Bio, Vertical Traction Elt, Leg Extension Med, Hexagon dumbbells, Abdominal Crunch ROM, Loop band, Lat Machine, Leg extension ROM
# Strength Training
# Tricep Press:Strength Training
# Cross Over Cables:Strength Training
# Medicine Ball:Functional Training
# Seated Dip Pure:Strength Training
# Vario Excite 500:Cardiovascular
# Top Excite Live:Cardiovascular
# Gym Ladder:Functional Training
# Lower Back Med:Functional Training
# Ercolina Rehab Elt+:Flexibility & Mobility
# Water 8ball:Functional Training
# Battle Rope:Functional Training
# Synchro without ramp:Cardiovascular
# Chest Press Med:Strength Training
# Hip Thrust Pure:Strength Training
# Kinesis Delta:Functional Training
# Elastic band:Flexibility & Mobility
# Kettle Blocks:Free Weights
# Arm Curl:Strength Training
# Run Personal:Cardiovascular
# Multi Hip Med:Strength Training
# Step Excite 1000:Cardiovascular
# Vertical Traction:Strength Training
# Easy Power Station:Strength Training
# Calf Machine Standing:Strength Training
# Chest Press Bio:Strength Training
# Bike 12L:Cardiovascular
# Row Race:Cardiovascular
# Step Excite 700:Cardiovascular
# Adductor Machine:Strength Training
# Arm Extension Elt:Strength Training
# Calf Machine Sitting: Strength Training
# Rings: Functional Training
# Hack Squat Pure: Strength Training
# Wave Excite 700: Cardiovascular
# Seated Calf Pure: Strength Training
# Abdominal Crunch Bio: Strength Training
# Synchro Excite Live: Cardiovascular
# Recline Personal: Flexibility & Mobility
# Technogym Bench: Strength Training
# Abductor Machine: Strength Training
# Ercolina Rehab Sel:Flexibility & Mobility
# Standing Abductor Pure:Strength Training
# Bike Med:Cardiovascular
# Low Row Med:Strength Training
# Lower Back ROM:Flexibility & Mobility
# Shoulder Press:Strength Training
# Upper Back Med:Strength Training
# Pullover Machine:Strength Training
# Horizontal Leg Press:Strength Training
# Lower Back Bio:Functional Training
# Ball Trampoline: Functional Training
# Crossover Excite 500: Cardiovascular
# Adjustable Ab/Crunch Pure: Strength Training
# Technogym Cycle: Cardiovascular
# Training ladder: Functional Training
# Big Tubing: Functional Training
# Bike Personal: Cardiovascular
# Standing Gluteus: Strength Training
# Sitting Leg Curl ROM: Strength Training
# Activities: Functional Training
# Recline Excite 500:Cardiovascular
# GHD Bench:Functional Training
# Leg Press Biostrength:Strength Training
# Lower Back Biostrength:Strength Training
# Total Abdom. Biostrength:Strength Training
# Speed ladder:Functional Training
# Dips Bar:Strength Training
# Kinesis Personal:Functional Training
# T-Row Bar:Strength Training
# Adductor Med:Strength Training
# Pectoral Med:Strength Training
# Ercolina Med:Strength Training
# Smart dips bar:Strength Training
# Pullover Pure:Strength Training
# Technogym Elliptical:Cardiovascular
# High & Low Pull Plr:Strength Training
# Leg press REV:Strength Training
# Jog Excite 500:Cardiovascular
# Kinesis Personal Beta:Functional Training
# Kinesis Personal Gamma:Functional Training
# Leg extension REV:Strength Training
# Rotary Torso Med:Functional Training
# Twin Clubs:Functional Training
# Press & Overhead Press Plr:Strength Training
# Step Excite 500:Cardiovascular
# Leg Curl Bio:Strength Training
# Leg Press Bio:Strength Training
# Myrun:Cardiovascular
# Unica Classic:Strength Training
# Plyo Board:Functional Training
# Hamstring Gluteus:Functional Training
# Pull-up bar:Strength Training
# Mobility ball:Flexibility & Mobility
# Rotex XT:Strength Training
# Bike Excite 700 12L:Cardiovascular
# Bike REV:Cardiovascular
# Synchro Forma:Cardiovascular
# Technogym Run:Cardiovascular
# Run Med:Cardiovascular
# Jumping box H600:Functional Training
# Battle rope:Functional Training
# Wave Excite 500:Cardiovascular
# Core & Leg Ext-Curl Plr:Strength Training
# Jumping box H300:Functional Training
# Run XT:Cardiovascular
# Punching bag:Functional Training
# Lat bar:Strength Training
# Pistols:Functional Training
# Wall bar:Functional Training
# Kinesis Personal Stretch:Flexibility & Mobility

# %%
# Write the string full_response to a file
with open('equip_categories.txt', 'w') as file:
    file.write(full_response)

# %%
# Define the path to the file
file_path = 'data/equip_categories.txt'

# Initialize an empty dictionary to store the equipment-category map
equipment_category_map = {}

# Open and read the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Process each line
for line in lines:
    line = line.strip()  # Remove extra spaces or newline characters
    if line:
        print(line)  # Check if the line is not empty
        equipment, category = line.rsplit(':', 1)
        equipment_category_map[equipment.strip()] = category.strip()

# Print or return the resulting map
print(equipment_category_map)
# Out:
# Bike:Cardiovascular
# Run:Cardiovascular
# Leg Curl Biostr:Strength Training
# Leg Press Biostr:Strength Training
# Leg Extension Sel:Strength Training
# Cables Crossed Elt+:Functional Training
# Dumbbells:Free Weights
# Barbell:Free Weights
# Body weight:Functional Training
# Kettlebell:Functional Training
# Wellness Ball:Flexibility & Mobility
# Climb Excite 1000:Cardiovascular
# Skillrow:Cardiovascular
# Skillrun:Cardiovascular
# Chest Press Sel:Strength Training
# Vertical Tr. Artis:Functional Training
# Total Abd. Artis:Functional Training
# Abductor Artis:Functional Training
# Synchro Excite 1000:Cardiovascular
# Climb Excite Live:Cardiovascular
# Tubes: Functional Training
# Cable Stations: Functional Training
# Cable Stations 4: Functional Training
# Row Pure: Strength Training
# Chest Press Pure: Strength Training
# Run Excite 1000: Cardiovascular
# Synchro Excite 700: Cardiovascular
# Arm Extension Sel: Strength Training
# Synchro Artis: Cardiovascular
# Bike Excite 1000: Cardiovascular
# Run Excite Live: Cardiovascular
# Rear Kick Pure:Functional Training
# Leg Press Sel:Strength Training
# Total Abdominal Sel:Strength Training
# Lower Back Sel:Strength Training
# Synchro Artis 2019:Cardiovascular
# Multipower:Strength Training
# Pectoral Sel:Strength Training
# Shoulder Press Sel:Strength Training
# Anterior Flexability:Flexibility & Mobility
# Run Excite 600:Cardiovascular
# Pulley Sel:Functional Training
# Cables Crossed Sel:Functional Training
# Total Abdom. Biostr:Strength Training
# Vertical Tr. Biostr:Strength Training
# Crossover Cables:Strength Training
# Recline:Strength Training
# Wave:Cardiovascular
# Lat Machine Sel:Strength Training
# Arm Extension Artis:Strength Training
# Shoulder Press Artis:Strength Training
# Low Row Artis:Strength Training
# Cable Jungle:Functional Training
# Lower Back Bench:Strength Training
# Leg Curl Elt+:Strength Training
# Leg Curl Sel:Strength Training
# Adductor Artis:Strength Training
# Chest Press Biostr:Strength Training
# Low Row Biostr:Strength Training
# Step/Squat Kst:Functional Training
# High Pull Kst:Strength Training
# Leg Curl Artis: Strength Training
# Chest Press Artis: Strength Training
# Adductor Sel: Strength Training
# Abdominal Crunch Sel: Strength Training
# Leg Extension Artis: Strength Training
# Vario Excite Live: Cardiovascular
# Vertical Traction Sel: Strength Training
# Shoulder P. Biostr: Strength Training
# Leg Extension Biostr: Strength Training
# Easy Chin/Dip Sel: Strength Training
# Plyobox:Functional Training
# Technogym Bike:Cardiovascular
# Abductor Sel:Strength Training
# Adductor Elt+:Strength Training
# Lower Back Biostr:Strength Training
# Low Pull Kst:Strength Training
# Cambered Barbell:Free Weights
# Jump rope:Cardiovascular
# Upper Back Sel:Strength Training
# Pectoral Artis:Strength Training
# Power band:Functional Training
# Low Row Sel:Strength Training
# Leg Curl:Strength Training
# Recline Excite 1000:Cardiovascular
# Top:Strength Training
# Low Row Elt+:Strength Training
# Leg Press Elt+:Strength Training
# Glute Elt+:Strength Training
# Synchro Excite Compact:Cardiovascular
# Synchro:Cardiovascular
# Stretching:Flexibility & Mobility
# Leg Press Pure:Strength Training
# Arm Curl Elt+:Strength Training
# Abdominal Crunch Elt+:Strength Training
# Synchro ARTIS with ramp:Cardiovascular
# Dap Elt+:Functional Training
# Lower Back Elt+:Strength Training
# Sling trainer:Functional Training
# Leg Press Artis:Strength Training
# Prone Leg Curl Sel:Strength Training
# Vario Excite 1000:Cardiovascular
# Omnia:Functional Training
# Climb:Cardiovascular
# Vario Excite 700:Cardiovascular
# Synchro with ramp:Cardiovascular
# Posterior Flexability:Flexibility & Mobility
# Core Crunch Kst:Strength Training
# Abductor Elt+:Strength Training
# Vario:Cardiovascular
# Run Excite 700:Cardiovascular
# Leg Press Med:Strength Training
# Crunch Bench:Strength Training
# Synchro Excite LiveR:Cardiovascular
# Core Rotation Kst:Functional Training
# Lower Back Artis:Strength Training
# Kinesis Omega/One: Vertical:Functional Training
# Kinesis Omega/One: Low:Functional Training
# Kn. EasyChinDip Elt+:Strength Training
# Rotary Torso Sel:Strength Training
# Lat Machine Elt+:Strength Training
# Shoulder Press Elt:Strength Training
# Cables Crossed Elt:Functional Training
# Multi Hip Sel:Strength Training
# Lat Machine Artis:Strength Training
# Glute Sel:Strength Training
# Skillbike:Cardiovascular
# Rear Delt Row Artis:Strength Training
# Foam Roller:Flexibility & Mobility
# Arm Curl Artis:Strength Training
# Vario Artis:Cardiovascular
# Medicine Ball Arke:Functional Training
# Kinesis Omega/One: Functional Training
# Multi Hip Artis: Strength Training
# Abductor Elt: Strength Training
# Adductor Elt: Strength Training
# Skillrun TX 500: Cardiovascular
# Vertical Traction Elt+: Strength Training
# Chest Press Elt+: Strength Training
# Leg Extension Elt+: Strength Training
# Run Excite 500: Cardiovascular
# Synchro Excite 500: Cardiovascular
# Pull Down Pure: Strength Training
# Pectoral Elt+: Strength Training
# Press Kst: Strength Training
# Linear Leg Press Pure: Strength Training
# Squat Artis: Strength Training
# Balance Dome: Functional Training
# Rotary Torso Artis: Strength Training
# Skillmill: Cardiovascular
# Radiant: Cardiovascular
# Mobility stick: Flexibility & Mobility
# Technogym Ride:Cardiovascular
# Recline Excite Live:Cardiovascular
# Shoulder Press Elt+:Strength Training
# Lat Machine Med:Strength Training
# Vertical Traction Med:Strength Training
# Abdominal Bench:Strength Training
# Pectoral/Reverse Fly:Strength Training
# Pulldown Sel:Strength Training
# Recline Excite 700:Cardiovascular
# Crossover:Functional Training
# Bike Excite 700:Cardiovascular
# Ercolina ROM:Flexibility & Mobility
# Bike Excite Live:Cardiovascular
# Biceps Pure:Strength Training
# Run Excite 900:Cardiovascular
# Abdominal Crunch Elt:Strength Training
# Delt Machine:Strength Training
# Pulley:Strength Training
# Tricep Station:Strength Training
# Abductor Med:Strength Training
# Abdominal Crunch Med:Strength Training
# Stability Disc:Functional Training
# Arm Extension Elt+:Strength Training
# Leg Raise / Dip:Strength Training
# Rotary Torso:Strength Training
# Chest Press:Strength Training
# Arm Curl Sel:Strength Training
# Kinesis Omega/One: High:Strength Training
# Jog Excite 700:Cardiovascular
# Run 25L:Cardiovascular
# Climb Artis:Cardiovascular
# Ab Crunch Elt+:Strength Training
# Chin Up/Dip Leg Raise:Functional Training
# Calf Pure:Strength Training
# Olympic Half Rack Pure:Strength Training
# Shoulder Press Med:Strength Training
# Reverse Fly Sel:Strength Training
# Lat Machine Elt:Strength Training
# Leg Press Elt:Strength Training
# Leg Extension Biostrength:Strength Training
# Overhead Press Kst:Strength Training
# Arm Curl Elt:Strength Training
# Crunch Bench Elt:Strength Training
# Crossover Excite 1000:Functional Training
# Lower Back Elt:Strength Training
# Wellness Bag:Functional Training
# Group Cycle Connect:Cardiovascular
# Shoulder Press Pure:Strength Training
# Olympic Rack Pure:Strength Training
# Adjustable Bench Elt:Strength Training
# MYCYCLING:Cardiovascular
# Step:Cardiovascular
# Leg Extension Bio:Strength Training
# Leg Curl Med:Strength Training
# Chest Press Biostrength:Strength Training
# Vertical Tr. Biostrength:Strength Training
# Low Row Biostrength:Strength Training
# Low Row Elt:Strength Training
# Shoulder P. Biostrength:Strength Training
# Leg Curl Biostrength:Strength Training
# Stand Leg Curl Pure: Strength Training
# Leg Extension Pure: Strength Training
# Low Row Pure: Strength Training
# Balance Pad: Flexibility & Mobility
# Chest Incline Sel: Strength Training
# Top Excite 700: Cardiovascular
# Top Excite 1000: Cardiovascular
# Recline Artis: Cardiovascular
# Leg Curl/Leg Extension: Strength Training
# Flat Bench Sel: Strength Training
# Crossover Excite 700:Cardiovascular
# Kinesis Gamma:Functional Training
# Leg Curl Elt:Strength Training
# Pectoral Elt:Strength Training
# Kinesis Alpha:Functional Training
# Wellness Ball Active Sitting:Flexibility & Mobility
# Incline Chest Press Pure:Strength Training
# Rotary Calf Sel:Strength Training
# Kinesis Beta:Functional Training
# Chest Press Elt:Strength Training
# Glute Med:Strength Training
# Leg Extension Elt:Strength Training
# Vertical Row:Strength Training
# Glute Elt:Strength Training
# Air Ball:Functional Training
# Multipla:Strength Training
# Delts Machine Sel:Strength Training
# Bike Excite 500:Cardiovascular
# Pectoral Machine:Strength Training
# Cross Personal:Cardiovascular
# Water Ball:Functional Training
# Abductor/Adductor:Strength Training
# Pratica:Strength Training
# Pendulum:Strength Training
# Power Personal:Strength Training
# Unica:Strength Training
# Standing Leg Curl:Strength Training
# Wide Chest Press Pure:Strength Training
# Leg Press Disc Load:Strength Training
# Slam ball:Functional Training
# Wellness Rack:Strength Training
# Vertical Traction Bio:Strength Training
# Rowing Torso Bio:Strength Training
# Vertical Traction Elt:Strength Training
# Leg Extension Med:Strength Training
# Hexagon dumbbells:Strength Training
# Abdominal Crunch ROM:Strength Training
# Loop band:Strength Training
# Lat Machine:Strength Training
# Leg extension ROM:Strength Training
# Tricep Press:Strength Training
# Cross Over Cables:Strength Training
# Medicine Ball:Functional Training
# Seated Dip Pure:Strength Training
# Vario Excite 500:Cardiovascular
# Top Excite Live:Cardiovascular
# Gym Ladder:Functional Training
# Lower Back Med:Functional Training
# Ercolina Rehab Elt+:Flexibility & Mobility
# Water 8ball:Functional Training
# Battle Rope:Functional Training
# Synchro without ramp:Cardiovascular
# Chest Press Med:Strength Training
# Hip Thrust Pure:Strength Training
# Kinesis Delta:Functional Training
# Elastic band:Flexibility & Mobility
# Kettle Blocks:Free Weights
# Arm Curl:Strength Training
# Run Personal:Cardiovascular
# Multi Hip Med:Strength Training
# Step Excite 1000:Cardiovascular
# Vertical Traction:Strength Training
# Easy Power Station:Strength Training
# Calf Machine Standing:Strength Training
# Chest Press Bio:Strength Training
# Bike 12L:Cardiovascular
# Row Race:Cardiovascular
# Step Excite 700:Cardiovascular
# Adductor Machine:Strength Training
# Arm Extension Elt:Strength Training
# Calf Machine Sitting: Strength Training
# Rings: Functional Training
# Hack Squat Pure: Strength Training
# Wave Excite 700: Cardiovascular
# Seated Calf Pure: Strength Training
# Abdominal Crunch Bio: Strength Training
# Synchro Excite Live: Cardiovascular
# Recline Personal: Flexibility & Mobility
# Technogym Bench: Strength Training
# Abductor Machine: Strength Training
# Ercolina Rehab Sel:Flexibility & Mobility
# Standing Abductor Pure:Strength Training
# Bike Med:Cardiovascular
# Low Row Med:Strength Training
# Lower Back ROM:Flexibility & Mobility
# Shoulder Press:Strength Training
# Upper Back Med:Strength Training
# Pullover Machine:Strength Training
# Horizontal Leg Press:Strength Training
# Lower Back Bio:Functional Training
# Ball Trampoline: Functional Training
# Crossover Excite 500: Cardiovascular
# Adjustable Ab/Crunch Pure: Strength Training
# Technogym Cycle: Cardiovascular
# Training ladder: Functional Training
# Big Tubing: Functional Training
# Bike Personal: Cardiovascular
# Standing Gluteus: Strength Training
# Sitting Leg Curl ROM: Strength Training
# Activities: Functional Training
# Recline Excite 500:Cardiovascular
# GHD Bench:Functional Training
# Leg Press Biostrength:Strength Training
# Lower Back Biostrength:Strength Training
# Total Abdom. Biostrength:Strength Training
# Speed ladder:Functional Training
# Dips Bar:Strength Training
# Kinesis Personal:Functional Training
# T-Row Bar:Strength Training
# Adductor Med:Strength Training
# Pectoral Med:Strength Training
# Ercolina Med:Strength Training
# Smart dips bar:Strength Training
# Pullover Pure:Strength Training
# Technogym Elliptical:Cardiovascular
# High & Low Pull Plr:Strength Training
# Leg press REV:Strength Training
# Jog Excite 500:Cardiovascular
# Kinesis Personal Beta:Functional Training
# Kinesis Personal Gamma:Functional Training
# Leg extension REV:Strength Training
# Rotary Torso Med:Functional Training
# Twin Clubs:Functional Training
# Press & Overhead Press Plr:Strength Training
# Step Excite 500:Cardiovascular
# Leg Curl Bio:Strength Training
# Leg Press Bio:Strength Training
# Myrun:Cardiovascular
# Unica Classic:Strength Training
# Plyo Board:Functional Training
# Hamstring Gluteus:Functional Training
# Pull-up bar:Strength Training
# Mobility ball:Flexibility & Mobility
# Rotex XT:Strength Training
# Bike Excite 700 12L:Cardiovascular
# Bike REV:Cardiovascular
# Synchro Forma:Cardiovascular
# Technogym Run:Cardiovascular
# Run Med:Cardiovascular
# Jumping box H600:Functional Training
# Battle rope:Functional Training
# Wave Excite 500:Cardiovascular
# Core & Leg Ext-Curl Plr:Strength Training
# Jumping box H300:Functional Training
# Run XT:Cardiovascular
# Punching bag:Functional Training
# Lat bar:Strength Training
# Pistols:Functional Training
# Wall bar:Functional Training
# Kinesis Personal Stretch:Flexibility & Mobility
# {'Bike': 'Cardiovascular', 'Run': 'Cardiovascular', 'Leg Curl Biostr': 'Strength Training', 'Leg Press Biostr': 'Strength Training', 'Leg Extension Sel': 'Strength Training', 'Cables Crossed Elt+': 'Functional Training', 'Dumbbells': 'Free Weights', 'Barbell': 'Free Weights', 'Body weight': 'Functional Training', 'Kettlebell': 'Functional Training', 'Wellness Ball': 'Flexibility & Mobility', 'Climb Excite 1000': 'Cardiovascular', 'Skillrow': 'Cardiovascular', 'Skillrun': 'Cardiovascular', 'Chest Press Sel': 'Strength Training', 'Vertical Tr. Artis': 'Functional Training', 'Total Abd. Artis': 'Functional Training', 'Abductor Artis': 'Functional Training', 'Synchro Excite 1000': 'Cardiovascular', 'Climb Excite Live': 'Cardiovascular', 'Tubes': 'Functional Training', 'Cable Stations': 'Functional Training', 'Cable Stations 4': 'Functional Training', 'Row Pure': 'Strength Training', 'Chest Press Pure': 'Strength Training', 'Run Excite 1000': 'Cardiovascular', 'Synchro Excite 700': 'Cardiovascular', 'Arm Extension Sel': 'Strength Training', 'Synchro Artis': 'Cardiovascular', 'Bike Excite 1000': 'Cardiovascular', 'Run Excite Live': 'Cardiovascular', 'Rear Kick Pure': 'Functional Training', 'Leg Press Sel': 'Strength Training', 'Total Abdominal Sel': 'Strength Training', 'Lower Back Sel': 'Strength Training', 'Synchro Artis 2019': 'Cardiovascular', 'Multipower': 'Strength Training', 'Pectoral Sel': 'Strength Training', 'Shoulder Press Sel': 'Strength Training', 'Anterior Flexability': 'Flexibility & Mobility', 'Run Excite 600': 'Cardiovascular', 'Pulley Sel': 'Functional Training', 'Cables Crossed Sel': 'Functional Training', 'Total Abdom. Biostr': 'Strength Training', 'Vertical Tr. Biostr': 'Strength Training', 'Crossover Cables': 'Strength Training', 'Recline': 'Strength Training', 'Wave': 'Cardiovascular', 'Lat Machine Sel': 'Strength Training', 'Arm Extension Artis': 'Strength Training', 'Shoulder Press Artis': 'Strength Training', 'Low Row Artis': 'Strength Training', 'Cable Jungle': 'Functional Training', 'Lower Back Bench': 'Strength Training', 'Leg Curl Elt+': 'Strength Training', 'Leg Curl Sel': 'Strength Training', 'Adductor Artis': 'Strength Training', 'Chest Press Biostr': 'Strength Training', 'Low Row Biostr': 'Strength Training', 'Step/Squat Kst': 'Functional Training', 'High Pull Kst': 'Strength Training', 'Leg Curl Artis': 'Strength Training', 'Chest Press Artis': 'Strength Training', 'Adductor Sel': 'Strength Training', 'Abdominal Crunch Sel': 'Strength Training', 'Leg Extension Artis': 'Strength Training', 'Vario Excite Live': 'Cardiovascular', 'Vertical Traction Sel': 'Strength Training', 'Shoulder P. Biostr': 'Strength Training', 'Leg Extension Biostr': 'Strength Training', 'Easy Chin/Dip Sel': 'Strength Training', 'Plyobox': 'Functional Training', 'Technogym Bike': 'Cardiovascular', 'Abductor Sel': 'Strength Training', 'Adductor Elt+': 'Strength Training', 'Lower Back Biostr': 'Strength Training', 'Low Pull Kst': 'Strength Training', 'Cambered Barbell': 'Free Weights', 'Jump rope': 'Cardiovascular', 'Upper Back Sel': 'Strength Training', 'Pectoral Artis': 'Strength Training', 'Power band': 'Functional Training', 'Low Row Sel': 'Strength Training', 'Leg Curl': 'Strength Training', 'Recline Excite 1000': 'Cardiovascular', 'Top': 'Strength Training', 'Low Row Elt+': 'Strength Training', 'Leg Press Elt+': 'Strength Training', 'Glute Elt+': 'Strength Training', 'Synchro Excite Compact': 'Cardiovascular', 'Synchro': 'Cardiovascular', 'Stretching': 'Flexibility & Mobility', 'Leg Press Pure': 'Strength Training', 'Arm Curl Elt+': 'Strength Training', 'Abdominal Crunch Elt+': 'Strength Training', 'Synchro ARTIS with ramp': 'Cardiovascular', 'Dap Elt+': 'Functional Training', 'Lower Back Elt+': 'Strength Training', 'Sling trainer': 'Functional Training', 'Leg Press Artis': 'Strength Training', 'Prone Leg Curl Sel': 'Strength Training', 'Vario Excite 1000': 'Cardiovascular', 'Omnia': 'Functional Training', 'Climb': 'Cardiov ...

# %%
num_keys = len(equipment_category_map)
print(f"The category_map dictionary has {num_keys} keys.")
# Out:
# The category_map dictionary has 372 keys.

# %%
# Get the set of unique equipment names from the exercises dataframe
unique_equipment_names = set(exercises['EquipmentName'].dropna().unique())

# Get the set of keys from the category_map
category_map_keys = set(equipment_category_map.keys())

# Find the equipment names that are not in the category_map keys
unmapped_equipment_names = unique_equipment_names - category_map_keys

# Count the number of unmapped equipment names
num_unmapped_equipment_names = len(unmapped_equipment_names)

print(f"Number of values in the column EquipmentName that don't belong to the keys of the category map: {num_unmapped_equipment_names}")
# Out:
# Number of values in the column EquipmentName that don't belong to the keys of the category map: 0

# %%
# Print the equipment names that are not in the category_map keys
print("Equipment names missing from the category map:")
for equipment in unmapped_equipment_names:
    if equipment.strip() not in category_map_keys:
        print(equipment.strip())
# Out:
# Equipment names missing from the category map:

# %%
# Strip whitespace from the specified columns
columns_to_strip = ['EquipmentName', 'ExerciseMusclesName', 'ExerciseBodyPartName', 'ExerciseName']
for column in columns_to_strip:
    exercises[column] = exercises[column].str.strip()

# Display the first few rows to verify the changes
exercises.head()
# Out:
#                                     CloudId Gender  Age  \
# 0  ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 1  ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 2  ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 3  56a55ec8f237732fff2239735b469e346c8a5f6b      M   17
# 4  926bd1a7bbf9ccd40101befc6d409e2aa5979fd2      F   17
#
#   PhysicalActivityMacroTypeName             ExerciseName    EquipmentName  \
# 0                        Cardio  Custom exercise in time             Bike
# 1                        Cardio    GOAL exercise in time              Run
# 2                      Isotonic                 Leg curl  Leg Curl Biostr
# 3                        Cardio    GOAL exercise in time              Run
# 4                        Cardio    GOAL exercise in time              Run
#
#                           DoneOnUTC  Duration_sec  Calories  MetsMin  \
# 0  2022-01-23 10:00:31.425000+00:00           215      30.0      5.6
# 1  2022-01-23 10:09:01.153000+00:00           215      29.0      5.3
# 2  2022-01-23 10:28:49.724000+00:00            85       9.0      4.0
# 3  2022-01-23 08:52:44.240000+00:00           600      90.0      8.4
# 4  2022-01-23 17:13:38.840000+00:00           660     126.0      8.6
#
#   ExerciseBodyPartName ExerciseMusclesName  METs  EquipmentCategory
# 0            LowerBody                 NaN   NaN     Cardiovascular
# 1            TotalBody                 NaN   NaN     Cardiovascular
# 2                  NaN                 NaN   NaN  Strength Training
# 3            TotalBody                 NaN   NaN     Cardiovascular
# 4            TotalBody                 NaN   NaN     Cardiovascular

# %%
# Add a new column 'EquipmentCategory' to the exercises DataFrame
exercises['EquipmentCategory'] = exercises['EquipmentName'].map(equipment_category_map)

# Display the first few rows to verify the new column
exercises.head()
# Out:
#                                     CloudId Gender  Age  \
# 0  ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 1  ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 2  ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 3  56a55ec8f237732fff2239735b469e346c8a5f6b      M   17
# 4  926bd1a7bbf9ccd40101befc6d409e2aa5979fd2      F   17
#
#   PhysicalActivityMacroTypeName             ExerciseName    EquipmentName  \
# 0                        Cardio  Custom exercise in time             Bike
# 1                        Cardio    GOAL exercise in time              Run
# 2                      Isotonic                 Leg curl  Leg Curl Biostr
# 3                        Cardio    GOAL exercise in time              Run
# 4                        Cardio    GOAL exercise in time              Run
#
#                           DoneOnUTC  Duration_sec  Calories  MetsMin  \
# 0  2022-01-23 10:00:31.425000+00:00           215      30.0      5.6
# 1  2022-01-23 10:09:01.153000+00:00           215      29.0      5.3
# 2  2022-01-23 10:28:49.724000+00:00            85       9.0      4.0
# 3  2022-01-23 08:52:44.240000+00:00           600      90.0      8.4
# 4  2022-01-23 17:13:38.840000+00:00           660     126.0      8.6
#
#   ExerciseBodyPartName ExerciseMusclesName  METs  EquipmentCategory
# 0            LowerBody                 NaN   NaN     Cardiovascular
# 1            TotalBody                 NaN   NaN     Cardiovascular
# 2                  NaN                 NaN   NaN  Strength Training
# 3            TotalBody                 NaN   NaN     Cardiovascular
# 4            TotalBody                 NaN   NaN     Cardiovascular

# %%
# Filter the exercises DataFrame for rows where EquipmentName is not null and EquipmentCategory is null
missing_equipment_category = exercises[(exercises['EquipmentName'].notnull()) & (exercises['EquipmentCategory'].isnull())]
# Display the filtered records
missing_equipment_category
# Out:
# Empty DataFrame
# Columns: [CloudId, Gender, Age, PhysicalActivityMacroTypeName, ExerciseName, EquipmentName, DoneOnUTC, Duration_sec, Calories, MetsMin, ExerciseBodyPartName, ExerciseMusclesName, METs, EquipmentCategory]
# Index: []

# %%
exercises.isnull().sum()
# Out:
# CloudId                                0
# Gender                                 0
# Age                                    0
# PhysicalActivityMacroTypeName          0
# ExerciseName                           0
# EquipmentName                          3
# DoneOnUTC                              0
# Duration_sec                           0
# Calories                               3
# MetsMin                          2456592
# ExerciseBodyPartName              783304
# ExerciseMusclesName               863014
# METs                              870238
# EquipmentCategory                      3
# dtype: int64

# %% [markdown]
# ### Store unique muscles for each exercise

# %%
exercises['ExerciseMusclesName'].value_counts().head(15)
# Out:
# ExerciseMusclesName
# LateralsBack                            318728
# Quadriceps                              298402
# Pectorals                               272265
# TotalBody                               260611
# Abdominals                              222133
# LowerBody                               156493
# Deltoids                                110438
# Hamstrings                              107163
# Gluteus                                 102602
# LowerBack                                75629
# Gluteus|Quadriceps|Hamstrings|Calves     67488
# Oblique                                  67341
# Adductors                                62237
# Triceps                                  61881
# Biceps                                   57299
# Name: count, dtype: int64

# %%
unique_exercise_muscles_name = exercises['ExerciseMusclesName'].nunique()
print(f"Unique ExerciseMusclesName: {unique_exercise_muscles_name}")
# Out:
# Unique ExerciseMusclesName: 268

# %%
# Specify the column for which you want to extract unique values
column_name = 'ExerciseMusclesName'  # Change this to the desired column name
unique_values = exercises[column_name].dropna().unique()
unique_values_df = pd.DataFrame(unique_values, columns=[column_name])
unique_values_df.to_csv(f'unique_{column_name}.csv', index=False)

# %% [markdown]
# ##### Store processed dataframe to file

# %%
# Store the processed exercises dataframe to a new CSV file
exercises.to_csv('data_cleaned/processed_exercises.csv', index=False)
