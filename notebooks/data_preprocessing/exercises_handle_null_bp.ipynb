# %%
import os
import pandas as pd

# Dictionary to store dataframes with filenames as keys
dataframes = {}

# Path to the data folder
data_folder = 'data_cleaned/'

# Loop through all files in the data folder
for filename in os.listdir(data_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(data_folder, filename)
        df = pd.read_csv(file_path)
        dataframes[filename[:-4]] = df
# Out:
# /var/folders/3f/hpgbw8dd459305qvgctxmywc0000gn/T/ipykernel_36029/464355729.py:14: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np

# %%
exercises = dataframes['processed_exercises']

# %%
exercises
# Out:
#                                           CloudId Gender  Age  \
# 0        ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 1        ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 2        ed958cce9812f1b8607f8c8ab5836c1f450f858b      M   13
# 3        56a55ec8f237732fff2239735b469e346c8a5f6b      M   17
# 4        926bd1a7bbf9ccd40101befc6d409e2aa5979fd2      F   17
# ...                                           ...    ...  ...
# 3315935  085e357c669a8ee210e226cd39031bed758ef2a2      M   52
# 3315936  5067f71d21840f5f0110c27f23868d632f538c73      M   57
# 3315937  feb24f6275b43b6b4bf2432b2bb25675a9b59eef      M   57
# 3315938  9b61fad4c9689e3370f85590f79337bbdc2781f5      M   57
# 3315939  b01f2ad026801f73a10feaa849c025addf24fadb      M   23
#
#         PhysicalActivityMacroTypeName             ExerciseName  \
# 0                              Cardio  Custom exercise in time
# 1                              Cardio    GOAL exercise in time
# 2                            Isotonic                 Leg curl
# 3                              Cardio    GOAL exercise in time
# 4                              Cardio    GOAL exercise in time
# ...                               ...                      ...
# 3315935                        Cardio    GOAL exercise in time
# 3315936                        Cardio    GOAL exercise in time
# 3315937                        Cardio    GOAL exercise in time
# 3315938                        Cardio    GOAL exercise in time
# 3315939                        Cardio                      Run
#
#            EquipmentName                         DoneOnUTC  Duration_sec  \
# 0                   Bike  2022-01-23 10:00:31.425000+00:00           215
# 1                    Run  2022-01-23 10:09:01.153000+00:00           215
# 2        Leg Curl Biostr  2022-01-23 10:28:49.724000+00:00            85
# 3                    Run  2022-01-23 08:52:44.240000+00:00           600
# 4                    Run  2022-01-23 17:13:38.840000+00:00           660
# ...                  ...                               ...           ...
# 3315935          Synchro  2022-07-25 12:02:38.464000+00:00          1800
# 3315936          Synchro  2022-07-25 15:33:43.573000+00:00           780
# 3315937          Synchro  2022-07-25 15:37:38.940000+00:00           370
# 3315938          Synchro  2022-07-25 07:42:42.078000+00:00          1800
# 3315939        Skillmill  2022-07-25 12:32:01.301000+00:00           600
#
#          Calories  MetsMin ExerciseBodyPartName  \
# 0            30.0      5.6            LowerBody
# 1            29.0      5.3            TotalBody
# 2             9.0      4.0                  NaN
# 3            90.0      8.4            TotalBody
# 4           126.0      8.6            TotalBody
# ...           ...      ...                  ...
# 3315935     217.0      NaN            LowerBody
# 3315936     113.0      NaN            LowerBody
# 3315937      97.0      NaN            LowerBody
# 3315938     436.0      NaN            LowerBody
# 3315939      98.0      NaN            LowerBody
#
#                           ExerciseMusclesName  METs  EquipmentCategory
# 0                                         NaN   NaN     Cardiovascular
# 1                                         NaN   NaN     Cardiovascular
# 2                                         NaN   NaN  Strength Training
# 3                                         NaN   NaN     Cardiovascular
# 4                                         NaN   NaN     Cardiovascular
# ...                                       ...   ...                ...
# 3315935  Gluteus|Quadriceps|Hamstrings|Calves   7.3     Cardiovascular
# 3315936  Gluteus|Quadriceps|Hamstrings|Calves   7.9     Cardiovascular
# 3315937  Gluteus|Quadriceps|Hamstrings|Calves   7.0     Cardiovascular
# 3315938  Gluteus|Quadriceps|Hamstrings|Calves  10.6     Cardiovascular
# 3315939  Gluteus|Quadriceps|Hamstrings|Calves   5.1     Cardiovascular
#
# [3315940 rows x 14 columns]

# %%
distinct_equipment_names = exercises[exercises['ExerciseBodyPartName'].isnull()]['EquipmentName'].unique()
print(distinct_equipment_names)
# Out:
# ['Leg Curl Biostr' 'Leg Press Biostr' 'Leg Extension Sel'
#  'Cables Crossed Elt+' 'Dumbbells' 'Barbell' 'Body weight' 'Kettlebell'
#  'Wellness Ball' 'Climb Excite 1000' 'Skillrow' 'Skillrun'
#  'Chest Press Sel' 'Vertical Tr. Artis' 'Total Abd. Artis'
#  'Abductor Artis' 'Synchro Excite 1000' 'Climb Excite Live' 'Tubes'
#  'Cable Stations 4' 'Row Pure' 'Chest Press Pure' 'Run Excite 1000'
#  'Synchro Excite 700' 'Arm Extension Sel' 'Synchro Artis'
#  'Bike Excite 1000' 'Run Excite Live' 'Rear Kick Pure' 'Leg Press Sel'
#  'Total Abdominal Sel' 'Lower Back Sel' 'Synchro Artis 2019' 'Multipower'
#  'Pectoral Sel' 'Shoulder Press Sel' 'Anterior Flexability'
#  'Run Excite 600' 'Pulley Sel' 'Cables Crossed Sel' 'Total Abdom. Biostr'
#  'Vertical Tr. Biostr' 'Crossover Cables' 'Recline' 'Wave'
#  'Lat Machine Sel' 'Arm Extension Artis' 'Shoulder Press Artis'
#  'Low Row Artis' 'Cable Jungle' 'Lower Back Bench' 'Leg Curl Elt+'
#  'Leg Curl Sel' 'Adductor Artis' 'Chest Press Biostr' 'Low Row Biostr'
#  'Step/Squat Kst' 'High Pull Kst' 'Leg Curl Artis' 'Chest Press Artis'
#  'Adductor Sel' 'Abdominal Crunch Sel' 'Leg Extension Artis'
#  'Vario Excite Live' 'Vertical Traction Sel' 'Shoulder P. Biostr'
#  'Leg Extension Biostr' 'Easy Chin/Dip Sel' 'Plyobox' 'Technogym Bike'
#  'Abductor Sel' 'Adductor Elt+' 'Lower Back Biostr' 'Low Pull Kst'
#  'Cambered Barbell' 'Jump rope' 'Upper Back Sel' 'Pectoral Artis'
#  'Power band' 'Low Row Sel' 'Leg Curl' 'Recline Excite 1000' 'Top'
#  'Low Row Elt+' 'Leg Press Elt+' 'Glute Elt+' 'Synchro Excite Compact'
#  'Synchro' 'Stretching' 'Leg Press Pure' 'Arm Curl Elt+'
#  'Abdominal Crunch Elt+' 'Synchro ARTIS with ramp' 'Dap Elt+'
#  'Lower Back Elt+' 'Sling trainer' 'Leg Press Artis' 'Prone Leg Curl Sel'
#  'Vario Excite 1000' 'Omnia' 'Climb' 'Vario Excite 700'
#  'Synchro with ramp' 'Posterior Flexability' 'Core Crunch Kst'
#  'Abductor Elt+' 'Vario' 'Run Excite 700' 'Leg Press Med' 'Crunch Bench'
#  'Synchro Excite LiveR' 'Core Rotation Kst' 'Lower Back Artis'
#  'Kinesis Omega/One: Vertical' 'Kn. EasyChinDip Elt+' 'Rotary Torso Sel'
#  'Lat Machine Elt+' 'Shoulder Press Elt' 'Cables Crossed Elt'
#  'Multi Hip Sel' 'Lat Machine Artis' 'Glute Sel' 'Skillbike'
#  'Rear Delt Row Artis' 'Foam Roller' 'Arm Curl Artis' 'Vario Artis'
#  'Medicine Ball Arke' 'Kinesis Omega/One: Low' 'Multi Hip Artis'
#  'Abductor Elt' 'Adductor Elt' 'Skillrun TX 500' 'Vertical Traction Elt+'
#  'Chest Press Elt+' 'Leg Extension Elt+' 'Run Excite 500'
#  'Synchro Excite 500' 'Pull Down Pure' 'Pectoral Elt+' 'Press Kst'
#  'Linear Leg Press Pure' 'Squat Artis' 'Balance Dome' 'Rotary Torso Artis'
#  'Skillmill' 'Radiant' 'Mobility stick' 'Technogym Ride'
#  'Recline Excite Live' 'Shoulder Press Elt+' 'Lat Machine Med'
#  'Vertical Traction Med' 'Abdominal Bench' 'Pectoral/Reverse Fly'
#  'Pulldown Sel' 'Recline Excite 700' 'Crossover' 'Bike Excite 700'
#  'Ercolina ROM' 'Bike Excite Live' 'Biceps Pure' 'Run Excite 900'
#  'Abdominal Crunch Elt' 'Delt Machine' 'Pulley' 'Tricep Station'
#  'Abductor Med' 'Abdominal Crunch Med' 'Stability Disc'
#  'Arm Extension Elt+' 'Leg Raise / Dip' 'Rotary Torso' 'Chest Press'
#  'Arm Curl Sel' 'Kinesis Omega/One: High' 'Jog Excite 700' 'Run 25L'
#  'Climb Artis' 'Ab Crunch Elt+' 'Chin Up/Dip Leg Raise' 'Calf Pure'
#  'Olympic Half Rack Pure' 'Shoulder Press Med' 'Reverse Fly Sel'
#  'Lat Machine Elt' 'Leg Press Elt' 'Leg Extension Biostrength'
#  'Overhead Press Kst' 'Arm Curl Elt' 'Crunch Bench Elt'
#  'Crossover Excite 1000' 'Lower Back Elt' 'Wellness Bag'
#  'Group Cycle Connect' 'Shoulder Press Pure' 'Olympic Rack Pure'
#  'Adjustable Bench Elt' 'MYCYCLING' 'Step' 'Leg Extension Bio'
#  'Leg Curl Med' 'Chest Press Biostrength' 'Vertical Tr. Biostrength'
#  'Low Row Biostrength' 'Low Row Elt' 'Shoulder P. Biostrength'
#  'Leg Curl Biostrength' 'Stand Leg Curl Pure' 'Leg Extension Pure'
#  'Low Row Pure' 'Balance Pad' 'Chest Incline Sel' 'Top Excite 700'
#  'Top Excite 1000' 'Recline Artis' 'Leg Curl/Leg Extension'
#  'Flat Bench Sel' 'Crossover Excite 700' 'Kinesis Gamma' 'Leg Curl Elt'
#  'Pectoral Elt' 'Kinesis Alpha' 'Wellness Ball Active Sitting'
#  'Incline Chest Press Pure' 'Rotary Calf Sel' 'Kinesis Beta'
#  'Chest Press Elt' 'Glute Med' 'Leg Extension Elt' 'Vertical Row'
#  'Glute Elt' 'Air Ball' 'Multipla' 'Delts Machine Sel' 'Bike Excite 500'
#  'Pectoral Machine' 'Cross Personal' 'Water Ball' 'Abductor/Adductor'
#  'Pratica' 'Pendulum' 'Power Personal' 'Unica' 'Standing Leg Curl'
#  'Wide Chest Press Pure' 'Leg Press Disc Load' 'Slam ball' 'Wellness Rack'
#  'Vertical Traction Bio' 'Rowing Torso Bio' 'Vertical Traction Elt'
#  'Leg Extension Med' 'Hexagon dumbbells' 'Abdominal Crunch ROM'
#  'Loop band' 'Lat Machine' 'Leg extension ROM' 'Tricep Press'
#  'Cross Over Cables' 'Medicine Ball' 'Seated Dip Pure' 'Vario Excite 500'
#  'Top Excite Live' 'Gym Ladder' 'Lower Back Med' 'Ercolina Rehab Elt+'
#  'Water 8ball' 'Battle Rope' 'Synchro without ramp' 'Chest Press Med'
#  'Hip Thrust Pure' 'Kinesis Delta' 'Elastic band' 'Kettle Blocks'
#  'Arm Curl' 'Run Personal' 'Multi Hip Med' 'Step Excite 1000'
#  'Vertical Traction' 'Easy Power Station' 'Calf Machine Standing'
#  'Chest Press Bio' 'Bike 12L' 'Row Race' 'Step Excite 700'
#  'Adductor Machine' 'Arm Extension Elt' 'Calf Machine Sitting' 'Rings'
#  'Hack Squat Pure' 'Wave Excite 700' 'Seated Calf Pure'
#  'Abdominal Crunch Bio' 'Synchro Excite Live' 'Recline Personal'
#  'Technogym Bench' 'Abductor Machine' 'Ercolina Rehab Sel'
#  'Standing Abductor Pure' 'Bike Med' 'Low Row Med' 'Lower Back ROM'
#  'Shoulder Press' 'Upper Back Med' 'Pullover Machine'
#  'Horizontal Leg Press' 'Lower Back Bio' 'Ball Trampoline'
#  'Crossover Excite 500' 'Adjustable Ab/Crunch Pure' 'Technogym Cycle'
#  'Training ladder' 'Big Tubing' 'Bike Personal' 'Standing Gluteus'
#  'Sitting Leg Curl ROM' 'Activities' 'Recline Excite 500' 'GHD Bench'
#  'Leg Press Biostrength' 'Lower Back Biostrength'
#  'Total Abdom. Biostrength' 'Speed ladder' 'Dips Bar' 'Kinesis Personal'
#  'T-Row Bar' 'Adductor Med' 'Pectoral Med' 'Ercolina Med' 'Smart dips bar'
#  'Pullover Pure' 'Technogym Elliptical' 'High & Low Pull Plr'
#  'Leg press REV' 'Jog Excite 500' 'Kinesis Personal Beta'
#  'Kinesis Personal Gamma' 'Leg extension REV' 'Rotary Torso Med'
#  'Twin Clubs' 'Press & Overhead Press Plr' 'Step Excite 500'
#  'Leg Curl Bio' 'Leg Press Bio' 'Myrun' 'Unica Classic']

# %%
# Convert the numpy array to a pandas DataFrame
distinct_equipment_df = pd.DataFrame(distinct_equipment_names, columns=['EquipmentName'])

# Save the DataFrame to a CSV file
distinct_equipment_df.to_csv('data_cleaned/distinctequipmentnamesfornullbodypart.csv', index=False)

# %%
exercises['ExerciseBodyPartName'].value_counts()
# Out:
# ExerciseBodyPartName
# LowerBody    889990
# UpperBody    866923
# TotalBody    409057
# Core         366666
# Name: count, dtype: int64

# %% [markdown]
# Used chat to make the categorization

# %%
import re
# Define the path to the file
file_path = 'data_cleaned/body_part_categorized.csv'

# Initialize an empty dictionary to store the equipment-category map
bp_categories = {}

# Open and read the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Process each line
for line in lines:
    line = line.strip()  # Remove extra spaces or newline characters
    if line:
        print(line)  # Check if the line is not empty
        equipment, bpcategory = line.rsplit(':', 1)
        bp_categories[equipment.strip()] = bpcategory.strip()

# Print or return the resulting map
print(bp_categories)
# Out:
# Leg Curl Biostr:LowerBody
# Leg Press Biostr:LowerBody
# Leg Extension Sel:LowerBody
# Cables Crossed Elt+:UpperBody
# Dumbbells:UpperBody
# Barbell:UpperBody
# Body weight:TotalBody
# Kettlebell:TotalBody
# Wellness Ball:Core
# Climb Excite 1000:LowerBody
# Skillrow:TotalBody
# Skillrun:LowerBody
# Chest Press Sel:UpperBody
# Vertical Tr. Artis:UpperBody
# Total Abd. Artis:Core
# Abductor Artis:LowerBody
# Synchro Excite 1000:LowerBody
# Climb Excite Live:LowerBody
# Tubes:UpperBody
# Cable Stations 4:UpperBody
# Row Pure:UpperBody
# Chest Press Pure:UpperBody
# Run Excite 1000:LowerBody
# Synchro Excite 700:LowerBody
# Arm Extension Sel:UpperBody
# Synchro Artis:LowerBody
# Bike Excite 1000:LowerBody
# Run Excite Live:LowerBody
# Rear Kick Pure:LowerBody
# Leg Press Sel:LowerBody
# Total Abdominal Sel:Core
# Lower Back Sel:LowerBody
# Synchro Artis 2019:LowerBody
# Multipower:UpperBody
# Pectoral Sel:UpperBody
# Shoulder Press Sel:UpperBody
# Anterior Flexability:Core
# Run Excite 600:LowerBody
# Pulley Sel:UpperBody
# Cables Crossed Sel:UpperBody
# Total Abdom. Biostr:Core
# Vertical Tr. Biostr:UpperBody
# Crossover Cables:UpperBody
# Recline:LowerBody
# Wave:LowerBody
# Lat Machine Sel:UpperBody
# Arm Extension Artis:UpperBody
# Shoulder Press Artis:UpperBody
# Low Row Artis:UpperBody
# Cable Jungle:UpperBody
# Lower Back Bench:LowerBody
# Leg Curl Elt+:LowerBody
# Leg Curl Sel:LowerBody
# Adductor Artis:LowerBody
# Chest Press Biostr:UpperBody
# Low Row Biostr:UpperBody
# Step/Squat Kst:LowerBody
# High Pull Kst:UpperBody
# Leg Curl Artis:LowerBody
# Chest Press Artis:UpperBody
# Adductor Sel:LowerBody
# Abdominal Crunch Sel:Core
# Leg Extension Artis:LowerBody
# Vario Excite Live:LowerBody
# Vertical Traction Sel:UpperBody
# Shoulder P. Biostr:UpperBody
# Leg Extension Biostr:LowerBody
# Easy Chin/Dip Sel:UpperBody
# Plyobox:LowerBody
# Technogym Bike:LowerBody
# Abductor Sel:LowerBody
# Adductor Elt+:LowerBody
# Lower Back Biostr:LowerBody
# Low Pull Kst:UpperBody
# Cambered Barbell:UpperBody
# Jump rope:TotalBody
# Upper Back Sel:UpperBody
# Pectoral Artis:UpperBody
# Power band:UpperBody
# Low Row Sel:UpperBody
# Leg Curl:LowerBody
# Recline Excite 1000:LowerBody
# Top:UpperBody
# Low Row Elt+:UpperBody
# Leg Press Elt+:LowerBody
# Glute Elt+:LowerBody
# Synchro Excite Compact:LowerBody
# Synchro:LowerBody
# Stretching:Core
# Leg Press Pure:LowerBody
# Arm Curl Elt+:UpperBody
# Abdominal Crunch Elt+:Core
# Synchro ARTIS with ramp:LowerBody
# Dap Elt+:UpperBody
# Lower Back Elt+:LowerBody
# Sling trainer:Core
# Leg Press Artis:LowerBody
# Prone Leg Curl Sel:LowerBody
# Vario Excite 1000:LowerBody
# Omnia:TotalBody
# Climb:LowerBody
# Vario Excite 700:LowerBody
# Synchro with ramp:LowerBody
# Posterior Flexability:Core
# Core Crunch Kst:Core
# Abductor Elt+:LowerBody
# Vario:LowerBody
# Run Excite 700:LowerBody
# Leg Press Med:LowerBody
# Crunch Bench:Core
# Synchro Excite LiveR:LowerBody
# Core Rotation Kst:Core
# Lower Back Artis:LowerBody
# Kinesis Omega/One: Vertical:UpperBody
# Kn. EasyChinDip Elt+:UpperBody
# Rotary Torso Sel:Core
# Lat Machine Elt+:UpperBody
# Shoulder Press Elt:UpperBody
# Cables Crossed Elt:UpperBody
# Multi Hip Sel:LowerBody
# Lat Machine Artis:UpperBody
# Glute Sel:LowerBody
# Skillbike:LowerBody
# Rear Delt Row Artis:UpperBody
# Foam Roller:Core
# Arm Curl Artis:UpperBody
# Vario Artis:LowerBody
# Medicine Ball Arke:Core
# Kinesis Omega/One: Low:UpperBody
# Multi Hip Artis:LowerBody
# Abductor Elt:LowerBody
# Adductor Elt:LowerBody
# Skillrun TX 500:LowerBody
# Vertical Traction Elt+:UpperBody
# Chest Press Elt+:UpperBody
# Leg Extension Elt+:LowerBody
# Run Excite 500:LowerBody
# Synchro Excite 500:LowerBody
# Pull Down Pure:UpperBody
# Pectoral Elt+:UpperBody
# Press Kst:UpperBody
# Linear Leg Press Pure:LowerBody
# Squat Artis:LowerBody
# Balance Dome:Core
# Rotary Torso Artis:Core
# Skillmill:LowerBody
# Radiant:TotalBody
# Mobility stick:Core
# Technogym Ride:LowerBody
# Recline Excite Live:LowerBody
# Shoulder Press Elt+:UpperBody
# Lat Machine Med:UpperBody
# Vertical Traction Med:UpperBody
# Abdominal Bench:Core
# Pectoral/Reverse Fly:UpperBody
# Pulldown Sel:UpperBody
# Recline Excite 700:LowerBody
# Crossover:UpperBody
# Bike Excite 700:LowerBody
# Ercolina ROM:UpperBody
# Bike Excite Live:LowerBody
# Biceps Pure:UpperBody
# Run Excite 900:LowerBody
# Abdominal Crunch Elt:Core
# Delt Machine:UpperBody
# Pulley:UpperBody
# Tricep Station:UpperBody
# Abductor Med:LowerBody
# Abdominal Crunch Med:Core
# Stability Disc:Core
# Arm Extension Elt+:UpperBody
# Leg Raise / Dip:UpperBody
# Rotary Torso:Core
# Chest Press:UpperBody
# Arm Curl Sel:UpperBody
# Kinesis Omega/One: High:UpperBody
# Jog Excite 700:LowerBody
# Run 25L:LowerBody
# Climb Artis:LowerBody
# Ab Crunch Elt+:Core
# Chin Up/Dip Leg Raise:UpperBody
# Calf Pure:LowerBody
# Olympic Half Rack Pure:UpperBody
# Shoulder Press Med:UpperBody
# Reverse Fly Sel:UpperBody
# Lat Machine Elt:UpperBody
# Leg Press Elt:LowerBody
# Leg Extension Biostrength:LowerBody
# Overhead Press Kst:UpperBody
# Arm Curl Elt:UpperBody
# Crunch Bench Elt:Core
# Crossover Excite 1000:UpperBody
# Lower Back Elt:LowerBody
# Wellness Bag:Core
# Group Cycle Connect:LowerBody
# Shoulder Press Pure:UpperBody
# Olympic Rack Pure:UpperBody
# Adjustable Bench Elt:UpperBody
# MYCYCLING:LowerBody
# Step:LowerBody
# Leg Extension Bio:LowerBody
# Leg Curl Med:LowerBody
# Chest Press Biostrength:UpperBody
# Vertical Tr. Biostrength:UpperBody
# Low Row Biostrength:UpperBody
# Low Row Elt:UpperBody
# Shoulder P. Biostrength:UpperBody
# Leg Curl Biostrength:LowerBody
# Stand Leg Curl Pure:LowerBody
# Leg Extension Pure:LowerBody
# Low Row Pure:UpperBody
# Balance Pad:Core
# Chest Incline Sel:UpperBody
# Top Excite 700:UpperBody
# Top Excite 1000:UpperBody
# Recline Artis:LowerBody
# Leg Curl/Leg Extension:LowerBody
# Flat Bench Sel:UpperBody
# Crossover Excite 700:UpperBody
# Kinesis Gamma:UpperBody
# Leg Curl Elt:LowerBody
# Pectoral Elt:UpperBody
# Kinesis Alpha:UpperBody
# Wellness Ball Active Sitting:Core
# Incline Chest Press Pure:UpperBody
# Rotary Calf Sel:LowerBody
# Kinesis Beta:UpperBody
# Chest Press Elt:UpperBody
# Glute Med:LowerBody
# Leg Extension Elt:LowerBody
# Vertical Row:UpperBody
# Glute Elt:LowerBody
# Air Ball:Core
# Multipla:UpperBody
# Delts Machine Sel:UpperBody
# Bike Excite 500:LowerBody
# Pectoral Machine:UpperBody
# Cross Personal:UpperBody
# Water Ball:Core
# Abductor/Adductor:LowerBody
# Pratica:TotalBody
# Pendulum:UpperBody
# Power Personal:UpperBody
# Unica:UpperBody
# Standing Leg Curl:LowerBody
# Wide Chest Press Pure:UpperBody
# Leg Press Disc Load:LowerBody
# Slam ball:TotalBody
# Wellness Rack:UpperBody
# Vertical Traction Bio:UpperBody
# Rowing Torso Bio:Core
# Vertical Traction Elt:UpperBody
# Leg Extension Med:LowerBody
# Hexagon dumbbells:UpperBody
# Abdominal Crunch ROM:Core
# Loop band:UpperBody
# Lat Machine:UpperBody
# Leg extension ROM:LowerBody
# Tricep Press:UpperBody
# Cross Over Cables:UpperBody
# Medicine Ball:Core
# Seated Dip Pure:UpperBody
# Vario Excite 500:LowerBody
# Top Excite Live:UpperBody
# Gym Ladder:Core
# Lower Back Med:LowerBody
# Ercolina Rehab Elt+:UpperBody
# Water 8ball:Core
# Battle Rope:TotalBody
# Synchro without ramp:LowerBody
# Chest Press Med:UpperBody
# Hip Thrust Pure:LowerBody
# Kinesis Delta:UpperBody
# Elastic band:UpperBody
# Kettle Blocks:TotalBody
# Arm Curl:UpperBody
# Run Personal:LowerBody
# Multi Hip Med:LowerBody
# Step Excite 1000:LowerBody
# Vertical Traction:UpperBody
# Easy Power Station:UpperBody
# Calf Machine Standing:LowerBody
# Chest Press Bio:UpperBody
# Bike 12L:LowerBody
# Row Race:UpperBody
# Step Excite 700:LowerBody
# Adductor Machine:LowerBody
# Arm Extension Elt:UpperBody
# Calf Machine Sitting:LowerBody
# Rings:UpperBody
# Hack Squat Pure:LowerBody
# Wave Excite 700:LowerBody
# Seated Calf Pure:LowerBody
# Abdominal Crunch Bio:Core
# Synchro Excite Live:LowerBody
# Recline Personal:LowerBody
# Technogym Bench:UpperBody
# Abductor Machine:LowerBody
# Ercolina Rehab Sel:UpperBody
# Standing Abductor Pure:LowerBody
# Bike Med:LowerBody
# Low Row Med:UpperBody
# Lower Back ROM:LowerBody
# Shoulder Press:UpperBody
# Upper Back Med:UpperBody
# Pullover Machine:UpperBody
# Horizontal Leg Press:LowerBody
# Lower Back Bio:LowerBody
# Ball Trampoline:Core
# Crossover Excite 500:UpperBody
# Adjustable Ab/Crunch Pure:Core
# Technogym Cycle:LowerBody
# Training ladder:Core
# Big Tubing:UpperBody
# Bike Personal:LowerBody
# Standing Gluteus:LowerBody
# Sitting Leg Curl ROM:LowerBody
# Activities:TotalBody
# Recline Excite 500:LowerBody
# GHD Bench:LowerBody
# Leg Press Biostrength:LowerBody
# Lower Back Biostrength:LowerBody
# Total Abdom. Biostrength:Core
# Speed ladder:Core
# Dips Bar:UpperBody
# Kinesis Personal:UpperBody
# T-Row Bar:UpperBody
# Adductor Med:LowerBody
# Pectoral Med:UpperBody
# Ercolina Med:UpperBody
# Smart dips bar:UpperBody
# Pullover Pure:UpperBody
# Technogym Elliptical:LowerBody
# High & Low Pull Plr:UpperBody
# Leg press REV:LowerBody
# Jog Excite 500:LowerBody
# Kinesis Personal Beta:UpperBody
# Kinesis Personal Gamma:UpperBody
# Leg extension REV:LowerBody
# Rotary Torso Med:Core
# Twin Clubs:UpperBody
# Press & Overhead Press Plr:UpperBody
# Step Excite 500:LowerBody
# Leg Curl Bio:LowerBody
# Leg Press Bio:LowerBody
# Myrun:LowerBody
# Unica Classic:UpperBody
# {'Leg Curl Biostr': 'LowerBody', 'Leg Press Biostr': 'LowerBody', 'Leg Extension Sel': 'LowerBody', 'Cables Crossed Elt+': 'UpperBody', 'Dumbbells': 'UpperBody', 'Barbell': 'UpperBody', 'Body weight': 'TotalBody', 'Kettlebell': 'TotalBody', 'Wellness Ball': 'Core', 'Climb Excite 1000': 'LowerBody', 'Skillrow': 'TotalBody', 'Skillrun': 'LowerBody', 'Chest Press Sel': 'UpperBody', 'Vertical Tr. Artis': 'UpperBody', 'Total Abd. Artis': 'Core', 'Abductor Artis': 'LowerBody', 'Synchro Excite 1000': 'LowerBody', 'Climb Excite Live': 'LowerBody', 'Tubes': 'UpperBody', 'Cable Stations 4': 'UpperBody', 'Row Pure': 'UpperBody', 'Chest Press Pure': 'UpperBody', 'Run Excite 1000': 'LowerBody', 'Synchro Excite 700': 'LowerBody', 'Arm Extension Sel': 'UpperBody', 'Synchro Artis': 'LowerBody', 'Bike Excite 1000': 'LowerBody', 'Run Excite Live': 'LowerBody', 'Rear Kick Pure': 'LowerBody', 'Leg Press Sel': 'LowerBody', 'Total Abdominal Sel': 'Core', 'Lower Back Sel': 'LowerBody', 'Synchro Artis 2019': 'LowerBody', 'Multipower': 'UpperBody', 'Pectoral Sel': 'UpperBody', 'Shoulder Press Sel': 'UpperBody', 'Anterior Flexability': 'Core', 'Run Excite 600': 'LowerBody', 'Pulley Sel': 'UpperBody', 'Cables Crossed Sel': 'UpperBody', 'Total Abdom. Biostr': 'Core', 'Vertical Tr. Biostr': 'UpperBody', 'Crossover Cables': 'UpperBody', 'Recline': 'LowerBody', 'Wave': 'LowerBody', 'Lat Machine Sel': 'UpperBody', 'Arm Extension Artis': 'UpperBody', 'Shoulder Press Artis': 'UpperBody', 'Low Row Artis': 'UpperBody', 'Cable Jungle': 'UpperBody', 'Lower Back Bench': 'LowerBody', 'Leg Curl Elt+': 'LowerBody', 'Leg Curl Sel': 'LowerBody', 'Adductor Artis': 'LowerBody', 'Chest Press Biostr': 'UpperBody', 'Low Row Biostr': 'UpperBody', 'Step/Squat Kst': 'LowerBody', 'High Pull Kst': 'UpperBody', 'Leg Curl Artis': 'LowerBody', 'Chest Press Artis': 'UpperBody', 'Adductor Sel': 'LowerBody', 'Abdominal Crunch Sel': 'Core', 'Leg Extension Artis': 'LowerBody', 'Vario Excite Live': 'LowerBody', 'Vertical Traction Sel': 'UpperBody', 'Shoulder P. Biostr': 'UpperBody', 'Leg Extension Biostr': 'LowerBody', 'Easy Chin/Dip Sel': 'UpperBody', 'Plyobox': 'LowerBody', 'Technogym Bike': 'LowerBody', 'Abductor Sel': 'LowerBody', 'Adductor Elt+': 'LowerBody', 'Lower Back Biostr': 'LowerBody', 'Low Pull Kst': 'UpperBody', 'Cambered Barbell': 'UpperBody', 'Jump rope': 'TotalBody', 'Upper Back Sel': 'UpperBody', 'Pectoral Artis': 'UpperBody', 'Power band': 'UpperBody', 'Low Row Sel': 'UpperBody', 'Leg Curl': 'LowerBody', 'Recline Excite 1000': 'LowerBody', 'Top': 'UpperBody', 'Low Row Elt+': 'UpperBody', 'Leg Press Elt+': 'LowerBody', 'Glute Elt+': 'LowerBody', 'Synchro Excite Compact': 'LowerBody', 'Synchro': 'LowerBody', 'Stretching': 'Core', 'Leg Press Pure': 'LowerBody', 'Arm Curl Elt+': 'UpperBody', 'Abdominal Crunch Elt+': 'Core', 'Synchro ARTIS with ramp': 'LowerBody', 'Dap Elt+': 'UpperBody', 'Lower Back Elt+': 'LowerBody', 'Sling trainer': 'Core', 'Leg Press Artis': 'LowerBody', 'Prone Leg Curl Sel': 'LowerBody', 'Vario Excite 1000': 'LowerBody', 'Omnia': 'TotalBody', 'Climb': 'LowerBody', 'Vario Excite 700': 'LowerBody', 'Synchro with ramp': 'LowerBody', 'Posterior Flexability': 'Core', 'Core Crunch Kst': 'Core', 'Abductor Elt+': 'LowerBody', 'Vario': 'LowerBody', 'Run Excite 700': 'LowerBody', 'Leg Press Med': 'LowerBody', 'Crunch Bench': 'Core', 'Synchro Excite LiveR': 'LowerBody', 'Core Rotation Kst': 'Core', 'Lower Back Artis': 'LowerBody', 'Kinesis Omega/One: Vertical': 'UpperBody', 'Kn. EasyChinDip Elt+': 'UpperBody', 'Rotary Torso Sel': 'Core', 'Lat Machine Elt+': 'UpperBody', 'Shoulder Press Elt': 'UpperBody', 'Cables Crossed Elt': 'UpperBody', 'Multi Hip Sel': 'LowerBody', 'Lat Machine Artis': 'UpperBody', 'Glute Sel': 'LowerBody', 'Skillbike': 'LowerBody', 'Rear Delt Row Artis': 'UpperBody', 'Foam Roller': 'Core', 'Arm Curl Artis': 'UpperBody', 'Vario Artis': 'LowerBody', 'Medicine Ball Arke': 'Core', 'Kinesis Omega/One: Low': 'UpperBody', 'Multi Hip Artis': 'LowerBo ...

# %%
# Filter rows where ExerciseBodyPartName is null
null_bodypart_df = exercises[exercises['ExerciseBodyPartName'].isnull()]

# Check if EquipmentName is not in bp_categories keys
not_in_bp_categories = null_bodypart_df[~null_bodypart_df['EquipmentName'].isin(bp_categories.keys())]

# Get the count of such rows
count_not_in_bp_categories = not_in_bp_categories.shape[0]
print(count_not_in_bp_categories)
print(not_in_bp_categories)
# Out:
# 0
# Empty DataFrame
# Columns: [CloudId, Gender, Age, PhysicalActivityMacroTypeName, ExerciseName, EquipmentName, DoneOnUTC, Duration_sec, Calories, MetsMin, ExerciseBodyPartName, ExerciseMusclesName, METs, EquipmentCategory]
# Index: []

# %%
# Fill the ExerciseBodyPartName column based on the bp_categories dictionary
exercises['ExerciseBodyPartName'] = exercises.apply(
    lambda row: row['ExerciseBodyPartName'] if pd.notnull(row['ExerciseBodyPartName']) else bp_categories.get(row['EquipmentName'], None),
    axis=1
)

# %%
exercises.isnull().sum()
# Out:
# CloudId                                0
# Gender                                 0
# Age                                    0
# PhysicalActivityMacroTypeName          0
# ExerciseName                           0
# EquipmentName                          3
# DoneOnUTC                              0
# Duration_sec                           0
# Calories                               3
# MetsMin                          2456592
# ExerciseBodyPartName                   0
# ExerciseMusclesName               863014
# METs                              870238
# EquipmentCategory                      3
# dtype: int64

# %%
exercises.to_csv('data_cleaned/processed_exercises_v2.csv', index=False)
